# %% [markdown]
# # Objective
#
# 1. What are the comorbidities in SCZ patients?
# 2. Look into EHR for symptom scores? positive versus negative symptoms?
#
# ## Notes from Swarali
#
# Looking for schizophrenia comorbidities. Primarily:
# - OCD
# - Depression
#
# ## Conclusion (notes from Nish)
# 1. Identify a cohort of SCZ patients in an observation window
# 2. Restrict to continuous coverage
# 3. Look for all claims one year prior to and one year after index date in observation window
# 4. Look for the following comorbidities
#      - OCD
#      - Depression
#      - Add abuse?
# 5. Get age for the SCZ cohort and categorise into 5-yr groups
# 6. Compare age distribution with literature estimates for the US
# 7. Create weights for patients depending on their age to adjust for their under or over representation in the dataset
# 8. Create master table - 1 row per patients with their age, calculated weight, and binary (1/0) value for SCZ and each of the comorbidites listed above

# %% [markdown]
# ## Details
#
# `Observation window:` we are looking for people with a diagnosis of heart failure in the primary or secondary from 1st July 2015 to 31st June 2017
#
# `Index date:` this will be the first occurence of this diagnosis within the observation window
#
# `Look-back:` we will look back 1 year from the index date
#
# `Look-forward:` we will look forward 1 year from the index date
#
# `Continuous coverage:` this is the time period spanning 1 year prior to, and 1 year from the index date, over which patients have to be making medical pharmacy claims

# %% [markdown]
# <img src="in/cohort2.png", width=700>

# %% [markdown]
# # Intialisation Steps
# Connecting to Snowflake

# %% [markdown]
# ## Importing required modules

# %%
import pandas as pd
from drg_connect import Snowflake
import qgrid 
from datetime import timedelta, datetime
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Snowflake connection parameter

# %%
##defining parameters of snowflake
snow = Snowflake(role = 'RWD_ANALYTICS_RW',database='SANDBOX_ANALYTICS',schema = 'SANDBOX')
engine = snow.engine

# %reload_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# # Reference table
#
# Create a reference table to drive the analysis. This will include:
# 1. Diagnosis codes for SCZ
#
# Convert the table to lowercase

# %% [markdown]
# ## Dx codes

# %% [markdown]
# ### Schizophrenia

# %%
snow.select("select * from RWD_DB.RWD.ICD_GROUPER limit 3")
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
#    id     level_1                        level_1_description  level_2  \
# 0   1  A00 - B999  Certain infectious and parasitic diseases  A00-A09
# 1   2  A00 - B999  Certain infectious and parasitic diseases  A00-A09
# 2   3  A00 - B999  Certain infectious and parasitic diseases  A00-A09
#
#               level_2_description   level_3 level_3_description level_4  \
# 0  Intestinal infectious diseases  A00-A009             Cholera     A00
# 1  Intestinal infectious diseases  A00-A009             Cholera    A000
# 2  Intestinal infectious diseases  A00-A009             Cholera    A001
#
#   icd9_mapped_codes                       icd9_description  \
# 0            No map                                 No map
# 1              0010         Cholera due to vibrio cholerae
# 2              0011  Cholera due to vibrio cholerae el tor
#
#                      level_4_short_description_icd10  \
# 0                                            Cholera
# 1  Cholera due to Vibrio cholerae 01 biovar cholerae
# 2     Cholera due to Vibrio cholerae 01 biovar eltor
#
#                       level_4_long_description_icd10   create_ts   update_ts
# 0                                            Cholera  2017-11-02  2017-11-02
# 1  Cholera due to Vibrio cholerae 01 biovar cholerae  2017-11-02  2017-11-02
# 2     Cholera due to Vibrio cholerae 01 biovar eltor  2017-11-02  2017-11-02

# %%
# %%read_sql
#
# select
#     *
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     level_4_short_description_icd10 ilike '%schizophrenia%'
# Out:
# Query started at 05:07:17 PM India Standard Time; Query executed in 0.05 m
#      id    level_1                                level_1_description  \
# 0  5414  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 1  5415  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 2  5416  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 3  5417  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 4  5418  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 5  5419  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 6  5420  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 7  5422  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 8  5423  F01 - F99  Mental Behavioral and Neurodevelopmental disor...
#
#    level_2                                level_2_description   level_3  \
# 0  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 1  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 2  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 3  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 4  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 5  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 6  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 7  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
# 8  F20-F29  Schizophrenia schizotypal delusional and other...  F20-F209
#
#   level_3_description level_4 icd9_mapped_codes  \
# 0       Schizophrenia     F20            No map
# 1       Schizophrenia    F200             29530
# 2       Schizophrenia    F201             29510
# 3       Schizophrenia    F202             29520
# 4       Schizophrenia    F203            No map
# 5       Schizophrenia    F205             29560
# 6       Schizophrenia    F208            No map
# 7       Schizophrenia   F2089             29500
# 8       Schizophrenia    F209             29590
#
#                                     icd9_description  \
# 0                                             No map
# 1            Paranoid type schizophrenia unspecified
# 2        Disorganized type schizophrenia unspecified
# 3           Catatonic type schizophrenia unspecified
# 4                                             No map
# 5  Schizophrenic disorders residual type unspecified
# 6                                             No map
# 7              Simple type schizophrenia unspecified
# 8              Unspecified schizophrenia unspecified
#
#   level_4_short_description_icd10  level_4_long_description_icd10   create_ts  \
# 0                   Schizophrenia                   Schizophrenia  2017-11-02
# 1          Paranoid schizophrenia          Paranoid schizophrenia  2017-11-02
# 2      Disorganized schizophrenia      Disorganized schizophrenia  2017-11-02
# 3         Catatonic schizophrenia         Catatonic schizophrenia  2017-11-02
# 4  Undifferentiated schizophrenia  Undifferentiated schizophrenia  2017-11-02
# 5          Residual schizophrenia          Residual schizophrenia  2017-11-02
# 6             Other schizophrenia             Other schizophrenia  2017-11-02
# 7             Other schizophrenia             Other schizophrenia  2017-11-02
# 8       Schizophrenia unspecified       Schizophrenia unspecified  2017-11-02
#
#     update_ts
# 0  2017-11-02
# 1  2017-11-02
# 2  2017-11-02
# 3  2017-11-02
# 4  2017-11-02
# 5  2017-11-02
# 6  2017-11-02
# 7  2017-11-02
# 8  2017-11-02

# %%
# %%read_sql
#
# create or replace temporary table st_ssa_ref1 as
#
# select
#     'dx' as cat1,
#     'scz' cat2,
#     null as cat3,
#     null as cat4,
#     null as cat5,
#     null as cat6,
#     'icd_10' as type,
#     level_4 as value,
#     level_4_long_description_icd10 as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.ICD_GROUPER' as source
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     level_4_short_description_icd10 ilike '%schizophrenia%'
# Out:
# Query started at 02:09:10 PM India Standard Time; Query executed in 0.06 m
#                                     status
# 0  Table ST_SSA_REF1 successfully created.

# %%
# %%read_sql
#
# create or replace temporary table st_ssa_ref2 as
#
# select
#     'dx' as cat1,
#     'scz' cat2,
#     null as cat3,
#     null as cat4,
#     null as cat5,
#     null as cat6,
#     'icd_9' as type,
#     icd9_mapped_codes as value,
#     icd9_description as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.ICD_GROUPER' as source
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     level_4_short_description_icd10 ilike '%schizophrenia%'
# Out:
# Query started at 02:09:16 PM India Standard Time; Query executed in 0.05 m
#                                     status
# 0  Table ST_SSA_REF2 successfully created.

# %% [markdown]
# ### Comorbidities of interest

# %%
# %%read_sql
#
# select
#     *
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     (level_4_long_description_icd10 ilike '%depressive%'
#      and level_4_long_description_icd10 ilike '%disorder%')
#     or (level_4_long_description_icd10 ilike '%obsessive%'
#         and level_4_long_description_icd10 ilike '%compulsive%'
#        and level_4_long_description_icd10 ilike '%disorder%')
#     or level_4_long_description_icd10 ilike '%dementia%'
#     or (level_4_long_description_icd10 ilike '%alcohol%'
#      and level_4_long_description_icd10 ilike '%abuse%')
#      or (level_4_long_description_icd10 ilike '%opioid%'
#      and level_4_long_description_icd10 ilike '%abuse%')
# order by 1
# Out:
# Query started at 02:04:26 PM India Standard Time; Query executed in 0.05 m
#        id      level_1                                level_1_description  \
# 0    4828    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 1    4829    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 2    4830    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 3    4831    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 4    4832    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 5    4833    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 6    4834    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 7    4835    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 8    4836    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 9    4837    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 10   4838    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 11   4839    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 12   4848    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 13   4849    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 14   4862    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 15   4863    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 16   4864    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 17   4865    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 18   4866    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 19   4867    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 20   4868    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 21   4869    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 22   4870    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 23   4871    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 24   4872    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 25   4873    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 26   4874    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 27   4875    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 28   4876    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 29   4877    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# ..    ...          ...                                                ...
# 60   5430    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 61   5480    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 62   5481    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 63   5482    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 64   5483    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 65   5484    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 66   5485    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 67   5486    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 68   5490    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 69   5491    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 70   5492    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 71   5493    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 72   5494    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 73   5495    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 74   5496    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 75   5497    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 76   5498    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 77   5499    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 78   5500    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 79   5501    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 80   5548    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 81   5552    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 82   5553    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 83   5659    F01 - F99  Mental Behavioral and Neurodevelopmental disor...
# 84   5905   G00 - G998                     Diseases of the nervous system
# 85   5907   G00 - G998                     Diseases of the nervous system
# 86   5913   G00 - G998                     Diseases of the nervous system
# 87  93416  Z00 - Z9989  Factors influencing health status and contact ...
# 88  93417  Z00 - Z9989  Factors influencing health status and contact ...
# 89  93572  Z00 - Z9989  Factors influencing health status and contact ...
#
#     level_2                                level_2_description   level_3  \
# 0   F01-F09  Mental disorders due to known physiological co...  F01-F015
# 1   F01-F09  Mental disorders due to known physiological co...  F01-F015
# 2   F01-F09  Mental disorders due to known physiological co...  F01-F015
# 3   F01-F09  Mental disorders due to known physiological co...  F01-F015
# 4   F01-F09  Mental disorders due to known physiological co...  F02-F028
# 5   F01-F09  Mental disorders due to known physiological co...  F02-F028
# 6   F01-F09  Mental disorders due to known physiological co...  F02-F028
# 7   F01-F09  Mental disorders due to known physiological co...  F02-F028
# 8   F01-F09  Mental disorders due to known physiological co...  F03-F039
# 9   F01-F09  Mental disorders due to known physiological co...  F03-F039
# 10  F01-F09  Mental disorders due to known physiological co...  F03-F039
# 11  F01-F09  Mental disorders due to known physiological co...  F03-F039
# 12  F01-F09  Mental disorders due to known physiological co...  F06-F068
# 13  F01-F09  Mental disorders due to known physiological co...  F06-F068
# 14  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 15  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 16  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 17  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 18  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 19  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 20  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 21  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 22  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 23  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 24  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 25  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 26  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 27  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 28  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# 29  F10-F19  Mental and behavioral disorders due to psychoa...  F10-F109
# ..      ...                                                ...       ...
# 60  F20-F29  Schizophrenia schizotypal delusional and other...  F25-F259
# 61  F30-F39                         Mood [affective] disorders  F32-F329
# 62  F30-F39                         Mood [affective] disorders  F32-F329
# 63  F30-F39                         Mood [affective] disorders  F32-F329
# 64  F30-F39                         Mood [affective] disorders  F32-F329
# 65  F30-F39                         Mood [affective] disorders  F32-F329
# 66  F30-F39                         Mood [affective] disorders  F32-F329
# 67  F30-F39                         Mood [affective] disorders  F32-F329
# 68  F30-F39                         Mood [affective] disorders  F32-F329
# 69  F30-F39                         Mood [affective] disorders  F33-F339
# 70  F30-F39                         Mood [affective] disorders  F33-F339
# 71  F30-F39                         Mood [affective] disorders  F33-F339
# 72  F30-F39                         Mood [affective] disorders  F33-F339
# 73  F30-F39                         Mood [affective] disorders  F33-F339
# 74  F30-F39                         Mood [affective] disorders  F33-F339
# 75  F30-F39                         Mood [affective] disorders  F33-F339
# 76  F30-F39                         Mood [affective] disorders  F33-F339
# 77  F30-F39                         Mood [affective] disorders  F33-F339
# 78  F30-F39                         Mood [affective] disorders  F33-F339
# 79  F30-F39                         Mood [affective] disorders  F33-F339
# 80  F40-F48                        Anxiety dissociative stress  F42-F429
# 81  F40-F48                        Anxiety dissociative stress  F42-F429
# 82  F40-F48                        Anxiety dissociative stress  F42-F429
# 83  F60-F69        Disorders of adult personality and behavior  F60-F609
# 84  G30-G32  Other degenerative diseases of the nervous system  G31-G319
# 85  G30-G32  Other degenerative diseases of the nervous system  G31-G319
# 86  G30-G32  Other degenerative diseases of the nervous system  G31-G319
# 87  Z69-Z76  Persons encountering health services in other ...  Z71-Z719
# 88  Z69-Z76  Persons encountering health services in other ...  Z71-Z719
# 89  Z77-Z99  Persons with potential health hazards related ...  Z81-Z818
#
#                                   level_3_description level_4  \
# 0                                   Vascular dementia     F01
# 1                                   Vascular dementia    F015
# 2                                   Vascular dementia   F0150
# 3                                   Vascular dementia   F0151
# 4     Dementia in other diseases classified elsewhere     F02
# 5     Dementia in other diseases classified elsewhere    F028
# 6     Dementia in other diseases classified elsewhere   F0280
# 7     Dementia in other diseases classified elsewhere   F0281
# 8                                Unspecified dementia     F03
# 9                                Unspecified dementia    F039
# 10                               Unspecified dementia   F0390
# 11                               Unspecified dementia   F0391
# 12  Other mental disorders due to known physiologi...   F0631
# 13  Other mental disorders due to known physiologi...   F0632
# 14                          Alcohol related disorders    F101
# 15                          Alcohol related disorders   F1010
# 16                          Alcohol related disorders   F1011
# 17                          Alcohol related disorders   F1012
# 18                          Alcohol related disorders  F10120
# 19                          Alcohol related disorders  F10121
# 20                          Alcohol related disorders  F10129
# 21                          Alcohol related disorders   F1014
# 22                          Alcohol related disorders   F1015
# 23                          Alcohol related disorders  F10150
# 24                          Alcohol related disorders  F10151
# 25                          Alcohol related disorders  F10159
# 26                          Alcohol related disorders   F1018
# 27                          Alcohol related disorders  F10180
# 28                          Alcohol related disorders  F10181
# 29                          Alcohol related disorders  F10182
# ..                                                ...     ...
# 60                          Schizoaffective disorders    F251
# 61           Major depressive disorder single episode     F32
# 62           Major depressive disorder single episode    F320
# 63           Major depressive disorder single episode    F321
# 64           Major depressive disorder single episode    F322
# 65           Major depressive disorder single episode    F323
# 66           Major depressive disorder single episode    F324
# 67           Major depressive disorder single episode    F325
# 68           Major depressive disorder single episode    F329
# 69                Major depressive disorder recurrent     F33
# 70                Major depressive disorder recurrent    F330
# 71                Major depressive disorder recurrent    F331
# 72                Major depressive disorder recurrent    F332
# 73                Major depressive disorder recurrent    F333
# 74                Major depressive disorder recurrent    F334
# 75                Major depressive disorder recurrent   F3340
# 76                Major depressive disorder recurrent   F3341
# 77                Major depressive disorder recurrent   F3342
# 78                Major depressive disorder recurrent    F338
# 79                Major depressive disorder recurrent    F339
# 80                      Obsessive-compulsive disorder     F42
# 81                      Obsessive-compulsive disorder    F428
# 82                      Obsessive-compulsive disorder    F429
# 83                     Specific personality disorders    F605
# 84    Oth degenerative diseases of nervous system NEC    G310
# 85    Oth degenerative diseases of nervous system NEC   G3109
# 86    Oth degenerative diseases of nervous system NEC   G3183
# 87  Persons encntr health serv for oth cnsl and me...    Z714
# 88  Persons encntr health serv for oth cnsl and me...   Z7141
# 89  Family history of mental and behavioral disorders    Z811
#
#    icd9_mapped_codes                                   icd9_description  \
# 0             No map                                             No map
# 1             No map                                             No map
# 2              29040                    Vascular dementia uncomplicated
# 3              29041                    Vascular dementia with delirium
# 4             No map                                             No map
# 5             No map                                             No map
# 6              29410  Dementia in conditions classified elsewhere wi...
# 7              29411  Dementia in conditions classified elsewhere wi...
# 8             No map                                             No map
# 9             No map                                             No map
# 10              2900                      Senile dementia uncomplicated
# 11             29421   Dementia unspecified with behavioral disturbance
# 12            No map                                             No map
# 13            No map                                             No map
# 14            No map                                             No map
# 15             30500                          Alcohol abuse unspecified
# 16             30503                         Alcohol abuse in remission
# 17            No map                                             No map
# 18            No map                                             No map
# 19            No map                                             No map
# 20            No map                                             No map
# 21            No map                                             No map
# 22            No map                                             No map
# 23            No map                                             No map
# 24            No map                                             No map
# 25             29189             Other alcohol-induced mental disorders
# 26            No map                                             No map
# 27             29189             Other alcohol-induced mental disorders
# 28             29189             Other alcohol-induced mental disorders
# 29             29182                    Alcohol induced sleep disorders
# ..               ...                                                ...
# 60            No map                                             No map
# 61            No map                                             No map
# 62             29621  Major depressive affective disorder single epi...
# 63             29622  Major depressive affective disorder single epi...
# 64             29623  Major depressive affective disorder single epi...
# 65             29624  Major depressive affective disorder single epi...
# 66             29625  Major depressive affective disorder single epi...
# 67             29626  Major depressive affective disorder single epi...
# 68             29620  Major depressive affective disorder single epi...
# 69            No map                                             No map
# 70             29631  Major depressive affective disorder recurrent ...
# 71             29632  Major depressive affective disorder recurrent ...
# 72             29633  Major depressive affective disorder recurrent ...
# 73             29634  Major depressive affective disorder recurrent ...
# 74            No map                                             No map
# 75            No map                                             No map
# 76             29635  Major depressive affective disorder recurrent ...
# 77             29636  Major depressive affective disorder recurrent ...
# 78            No map                                             No map
# 79             29630  Major depressive affective disorder recurrent ...
# 80            No map                                             No map
# 81              3003                     Obsessive-compulsive disorders
# 82              3003                     Obsessive-compulsive disorders
# 83              3014          Obsessive-compulsive personality disorder
# 84            No map                                             No map
# 85             33119                      Other frontotemporal dementia
# 86             33182                          Dementia with lewy bodies
# 87            No map                                             No map
# 88             V6542              Counseling on substance use and abuse
# 89            No map                                             No map
#
#                       level_4_short_description_icd10  \
# 0                                   Vascular dementia
# 1                                   Vascular dementia
# 2    Vascular dementia without behavioral disturbance
# 3       Vascular dementia with behavioral disturbance
# 4     Dementia in other diseases classified elsewhere
# 5     Dementia in other diseases classified elsewhere
# 6   Dementia in oth diseases classd elswhr w/o beh...
# 7   Dementia in oth diseases classd elswhr w behav...
# 8                                Unspecified dementia
# 9                                Unspecified dementia
# 10  Unspecified dementia without behavioral distur...
# 11   Unspecified dementia with behavioral disturbance
# 12  Mood disorder due to known physiol cond w depr...
# 13  Mood disord d/t physiol cond w major depressiv...
# 14                                      Alcohol abuse
# 15                        Alcohol abuse uncomplicated
# 16                         Alcohol abuse in remission
# 17                    Alcohol abuse with intoxication
# 18      Alcohol abuse with intoxication uncomplicated
# 19           Alcohol abuse with intoxication delirium
# 20        Alcohol abuse with intoxication unspecified
# 21   Alcohol abuse with alcohol-induced mood disorder
# 22  Alcohol abuse with alcohol-induced psychotic d...
# 23  Alcohol abuse w alcoh-induce psychotic disorde...
# 24  Alcohol abuse w alcoh-induce psychotic disorde...
# 25  Alcohol abuse with alcohol-induced psychotic d...
# 26  Alcohol abuse with other alcohol-induced disor...
# 27  Alcohol abuse with alcohol-induced anxiety dis...
# 28  Alcohol abuse with alcohol-induced sexual dysf...
# 29  Alcohol abuse with alcohol-induced sleep disorder
# ..                                                ...
# 60           Schizoaffective disorder depressive type
# 61           Major depressive disorder single episode
# 62      Major depressive disorder single episode mild
# 63  Major depressive disorder single episode moderate
# 64  Major depressv disord single epsd sev w/o psyc...
# 65  Major depressv disord single epsd severe w psy...
# 66  Major depressv disorder single episode in part...
# 67  Major depressive disorder single episode in fu...
# 68  Major depressive disorder single episode unspe...
# 69                Major depressive disorder recurrent
# 70           Major depressive disorder recurrent mild
# 71       Major depressive disorder recurrent moderate
# 72  Major depressv disorder recurrent severe w/o p...
# 73  Major depressv disorder recurrent severe w psy...
# 74   Major depressive disorder recurrent in remission
# 75  Major depressive disorder recurrent in remissi...
# 76  Major depressive disorder recurrent in partial...
# 77  Major depressive disorder recurrent in full re...
# 78               Other recurrent depressive disorders
# 79    Major depressive disorder recurrent unspecified
# 80                      Obsessive-compulsive disorder
# 81                Other obsessive-compulsive disorder
# 82          Obsessive-compulsive disorder unspecified
# 83          Obsessive-compulsive personality disorder
# 84                            Frontotemporal dementia
# 85                      Other frontotemporal dementia
# 86                          Dementia with Lewy bodies
# 87          Alcohol abuse counseling and surveillance
# 88  Alcohol abuse counseling and surveillance of a...
# 89     Family history of alcohol abuse and dependence
#
#                        level_4_long_description_icd10   create_ts   update_ts
# 0                                   Vascular dementia  2017-11-02  2017-11-02
# 1                                   Vascular dementia  2017-11-02  2017-11-02
# 2    Vascular dementia without behavioral disturbance  2017-11-02  2017-11-02
# 3       Vascular dementia with behavioral disturbance  2017-11-02  2017-11-02
# 4     Dementia in other diseases classified elsewhere  2017-11-02  2017-11-02
# 5     Dementia in other diseases classified elsewhere  2017-11-02  2017-11-02
# 6   Dementia in other diseases classified elsewher...  2017-11-02  2017-11-02
# 7   Dementia in other diseases classified elsewher...  2017-11-02  2017-11-02
# 8                                Unspecified dementia  2017-11-02  2017-11-02
# 9                                Unspecified dementia  2017-11-02  2017-11-02
# 10  Unspecified dementia without behavioral distur...  2017-11-02  2017-11-02
# 11   Unspecified dementia with behavioral disturbance  2017-11-02  2017-11-02
# 12  Mood disorder due to known physiological condi...  2017-11-02  2017-11-02
# 13  Mood disorder due to known physiological condi...  2017-11-02  2017-11-02
# 14                                      Alcohol abuse  2017-11-02  2017-11-02
# 15                        Alcohol abuse uncomplicated  2017-11-02  2017-11-02
# 16                         Alcohol abuse in remission  2017-11-02  2017-11-02
# 17                    Alcohol abuse with intoxication  2017-11-02  2017-11-02
# 18      Alcohol abuse with intoxication uncomplicated  2017-11-02  2017-11-02
# 19           Alcohol abuse with intoxication delirium  2017-11-02  2017-11-02
# 20        Alcohol abuse with intoxication unspecified  2017-11-02  2017-11-02
# 21   Alcohol abuse with alcohol-induced mood disorder  2017-11-02  2017-11-02
# 22  Alcohol abuse with alcohol-induced psychotic d...  2017-11-02  2017-11-02
# 23  Alcohol abuse with alcohol-induced psychotic d...  2017-11-02  2017-11-02
# 24  Alcohol abuse with alcohol-induced psychotic d...  2017-11-02  2017-11-02
# 25  Alcohol abuse with alcohol-induced psychotic d...  2017-11-02  2017-11-02
# 26  Alcohol abuse with other alcohol-induced disor...  2017-11-02  2017-11-02
# 27  Alcohol abuse with alcohol-induced anxiety dis...  2017-11-02  2017-11-02
# 28  Alcohol abuse with alcohol-induced sexual dysf...  2017-11-02  2017-11-02
# 29  Alcohol abuse with alcohol-induced sleep disorder  2017-11-02  2017-11-02
# ..                                                ...         ...         ...
# 60           Schizoaffective disorder depressive type  2017-11-02  2017-11-02
# 61           Major depressive disorder single episode  2017-11-02  2017-11-02
# 62      Major depressive disorder single episode mild  2017-11-02  2017-11-02
# 63  Major depressive disorder single episode moderate  2017-11-02  2017-11-02
# 64  Major depressive disorder single episode sever...  2017-11-02  2017-11-02
# 65  Major depressive disorder single episode sever...  2017-11-02  2017-11-02
# 66  Major depressive disorder single episode in pa...  2017-11-02  2017-11-02
# 67  Major depressive disorder single episode in fu...  2017-11-02  2017-11-02
# 68  Major depressive disorder single episode unspe...  2017-11-02  2017-11-02
# 69                Major depressive disorder recurrent  2017-11-02  2017-11-02
# 70           Major depressive disorder recurrent mild  2017-11-02  2017-11-02
# 71       Major depressive disorder recurrent moderate  2017-11-02  2017-11-02
# 72  Major depressive disorder recurrent severe wit...  2017-11-02  2017-11-02
# 73  Major depressive disorder recurrent severe wit...  2017-11-02  2017-11-02
# 74   Major depressive disorder recurrent in remission  2017-11-02  2017-11-02
# 75  Major depressive disorder recurrent in remissi...  2017-11-02  2017-11-02
# 76  Major depressive disorder recurrent in partial...  2017-11-02  2017-11-02
# 77  Major depressive disorder recurrent in full re...  2017-11-02  2017-11-02
# 78               Other recurrent depressive disorders  2017-11-02  2017-11-02
# 79    Major depressive disorder recurrent unspecified  2017-11-02  2017-11-02
# 80                      Obsessive-compulsive disorder  2017-11-02  2017-11-02
# 81                Other obsessive-compulsive disorder  2017-11-02  2017-11-02
# 82          Obsessive-compulsive disorder unspecified  2017-11-02  2017-11-02
# 83          Obsessive-compulsive personality disorder  2017-11-02  2017-11-02
# 84                            Frontotemporal dementia  2017-11-02  2017-11-02
# 85                      Other frontotemporal dementia  2017-11-02  2017-11-02
# 86                          Dementia with Lewy bodies  2017-11-02  2017-11-02
# 87          Alcohol abuse counseling and surveillance  2017-11-02  2017-11-02
# 88  Alcohol abuse counseling and surveillance of a...  2017-11-02  2017-11-02
# 89     Family history of alcohol abuse and dependence  2017-11-02  2017-11-02
#
# [90 rows x 14 columns]

# %%
# %%read_sql
#
# --ICD10 temporary table for comorbidities
# create or replace temporary table st_ssa_ref3 as
#
# select
#     'dx' as cat1,
#     'comorbidity' cat2,
#     case
#         when (level_4_long_description_icd10 ilike '%depressive%'
#               and level_4_long_description_icd10 ilike '%disorder%') then 'depression'
#         when (level_4_long_description_icd10 ilike '%obsessive%'
#               and level_4_long_description_icd10 ilike '%compulsive%'
#               and level_4_long_description_icd10 ilike '%disorder%') then 'OCD'
#         when level_4_long_description_icd10 ilike '%dementia%' then 'dementia'
#         when (level_4_long_description_icd10 ilike '%alcohol%'
#              and level_4_long_description_icd10 ilike '%abuse%') then 'alcohol abuse'
#         when (level_4_long_description_icd10 ilike '%opioid%'
#              and level_4_long_description_icd10 ilike '%abuse%') then 'opioid abuse'
#         end as cat3,
#     level_1_description as cat4,
#     level_2_description as cat5,
#     level_3_description as cat6,
#     'icd_10' as type,
#     level_4 as value,
#     level_4_long_description_icd10 as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.ICD_GROUPER' as source
#
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#        (level_4_long_description_icd10 ilike '%depressive%'
#      and level_4_long_description_icd10 ilike '%disorder%')
#     or (level_4_long_description_icd10 ilike '%obsessive%'
#         and level_4_long_description_icd10 ilike '%compulsive%'
#        and level_4_long_description_icd10 ilike '%disorder%')
#     or level_4_long_description_icd10 ilike '%dementia%'
#     or (level_4_long_description_icd10 ilike '%alcohol%'
#          and level_4_long_description_icd10 ilike '%abuse%')
#      or (level_4_long_description_icd10 ilike '%opioid%'
#          and level_4_long_description_icd10 ilike '%abuse%')
# Out:
# Query started at 02:07:20 PM India Standard Time; Query executed in 0.08 m
#                                     status
# 0  Table ST_SSA_REF3 successfully created.

# %%
# %%read_sql
#
# --ICD9 temporary table for comorbidities
# create or replace temporary table st_ssa_ref4 as
#
# select
#     'dx' as cat1,
#     'comorbidity' cat2,
#     case
#         when (level_4_long_description_icd10 ilike '%depressive%'
#               and level_4_long_description_icd10 ilike '%disorder%') then 'depression'
#         when (level_4_long_description_icd10 ilike '%obsessive%'
#               and level_4_long_description_icd10 ilike '%compulsive%'
#               and level_4_long_description_icd10 ilike '%disorder%') then 'OCD'
#         when level_4_long_description_icd10 ilike '%dementia%' then 'dementia'
#         when (level_4_long_description_icd10 ilike '%alcohol%'
#              and level_4_long_description_icd10 ilike '%abuse%') then 'alcohol abuse'
#         when (level_4_long_description_icd10 ilike '%opioid%'
#              and level_4_long_description_icd10 ilike '%abuse%') then 'opioid abuse'
#         end as cat3,
#     level_1_description as cat4,
#     level_2_description as cat5,
#     level_3_description as cat6,
#     'icd_9' as type,
#     icd9_mapped_codes as value,
#     icd9_description as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.ICD_GROUPER' as source
#
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     icd9_mapped_codes != 'No map'
#     and ((level_4_long_description_icd10 ilike '%depressive%'
#          and level_4_long_description_icd10 ilike '%disorder%')
#     or (level_4_long_description_icd10 ilike '%obsessive%'
#         and level_4_long_description_icd10 ilike '%compulsive%'
#         and level_4_long_description_icd10 ilike '%disorder%')
#          or level_4_long_description_icd10 ilike '%dementia%'
#     or (level_4_long_description_icd10 ilike '%alcohol%'
#          and level_4_long_description_icd10 ilike '%abuse%')
#      or (level_4_long_description_icd10 ilike '%opioid%'
#          and level_4_long_description_icd10 ilike '%abuse%'))
# Out:
# Query started at 02:08:37 PM India Standard Time; Query executed in 0.08 m
#                                     status
# 0  Table ST_SSA_REF4 successfully created.

# %% [markdown]
# ## Combine

# %%
# %%read_sql df
#
# select * from st_ssa_ref1
# union
# select * from st_ssa_ref2
# union
# select * from st_ssa_ref3
# union
# select * from st_ssa_ref4
# Out:
# Query started at 02:09:26 PM India Standard Time; Query executed in 0.09 m
#     cat1         cat2           cat3  \
# 0     dx          scz           None
# 1     dx          scz           None
# 2     dx          scz           None
# 3     dx          scz           None
# 4     dx  comorbidity       dementia
# 5     dx  comorbidity       dementia
# 6     dx  comorbidity       dementia
# 7     dx  comorbidity  alcohol abuse
# 8     dx  comorbidity   opioid abuse
# 9     dx  comorbidity   opioid abuse
# 10    dx  comorbidity       dementia
# 11    dx  comorbidity       dementia
# 12    dx  comorbidity            OCD
# 13    dx  comorbidity       dementia
# 14    dx  comorbidity  alcohol abuse
# 15    dx  comorbidity   opioid abuse
# 16    dx  comorbidity   opioid abuse
# 17    dx  comorbidity     depression
# 18    dx  comorbidity       dementia
# 19    dx  comorbidity  alcohol abuse
# 20    dx  comorbidity   opioid abuse
# 21    dx  comorbidity   opioid abuse
# 22    dx  comorbidity     depression
# 23    dx  comorbidity  alcohol abuse
# 24    dx  comorbidity  alcohol abuse
# 25    dx  comorbidity   opioid abuse
# 26    dx  comorbidity     depression
# 27    dx  comorbidity       dementia
# 28    dx  comorbidity       dementia
# 29    dx  comorbidity       dementia
# ..   ...          ...            ...
# 111   dx  comorbidity       dementia
# 112   dx  comorbidity       dementia
# 113   dx  comorbidity  alcohol abuse
# 114   dx  comorbidity  alcohol abuse
# 115   dx  comorbidity       dementia
# 116   dx  comorbidity   opioid abuse
# 117   dx  comorbidity       dementia
# 118   dx  comorbidity     depression
# 119   dx  comorbidity  alcohol abuse
# 120   dx  comorbidity  alcohol abuse
# 121   dx  comorbidity     depression
# 122   dx  comorbidity     depression
# 123   dx  comorbidity     depression
# 124   dx  comorbidity   opioid abuse
# 125   dx  comorbidity       dementia
# 126   dx  comorbidity     depression
# 127   dx  comorbidity       dementia
# 128   dx  comorbidity     depression
# 129   dx  comorbidity       dementia
# 130   dx  comorbidity  alcohol abuse
# 131   dx  comorbidity       dementia
# 132   dx  comorbidity  alcohol abuse
# 133   dx  comorbidity  alcohol abuse
# 134   dx  comorbidity   opioid abuse
# 135   dx  comorbidity   opioid abuse
# 136   dx  comorbidity     depression
# 137   dx  comorbidity     depression
# 138   dx  comorbidity       dementia
# 139   dx  comorbidity            OCD
# 140   dx  comorbidity     depression
#
#                                                   cat4  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    Mental Behavioral and Neurodevelopmental disor...
# 5    Mental Behavioral and Neurodevelopmental disor...
# 6    Mental Behavioral and Neurodevelopmental disor...
# 7    Mental Behavioral and Neurodevelopmental disor...
# 8    Mental Behavioral and Neurodevelopmental disor...
# 9    Mental Behavioral and Neurodevelopmental disor...
# 10   Mental Behavioral and Neurodevelopmental disor...
# 11   Mental Behavioral and Neurodevelopmental disor...
# 12   Mental Behavioral and Neurodevelopmental disor...
# 13                      Diseases of the nervous system
# 14   Mental Behavioral and Neurodevelopmental disor...
# 15   Mental Behavioral and Neurodevelopmental disor...
# 16   Mental Behavioral and Neurodevelopmental disor...
# 17   Mental Behavioral and Neurodevelopmental disor...
# 18   Mental Behavioral and Neurodevelopmental disor...
# 19   Mental Behavioral and Neurodevelopmental disor...
# 20   Mental Behavioral and Neurodevelopmental disor...
# 21   Mental Behavioral and Neurodevelopmental disor...
# 22   Mental Behavioral and Neurodevelopmental disor...
# 23   Mental Behavioral and Neurodevelopmental disor...
# 24   Mental Behavioral and Neurodevelopmental disor...
# 25   Mental Behavioral and Neurodevelopmental disor...
# 26   Mental Behavioral and Neurodevelopmental disor...
# 27   Mental Behavioral and Neurodevelopmental disor...
# 28   Mental Behavioral and Neurodevelopmental disor...
# 29   Mental Behavioral and Neurodevelopmental disor...
# ..                                                 ...
# 111  Mental Behavioral and Neurodevelopmental disor...
# 112  Mental Behavioral and Neurodevelopmental disor...
# 113  Mental Behavioral and Neurodevelopmental disor...
# 114  Mental Behavioral and Neurodevelopmental disor...
# 115  Mental Behavioral and Neurodevelopmental disor...
# 116  Mental Behavioral and Neurodevelopmental disor...
# 117  Mental Behavioral and Neurodevelopmental disor...
# 118  Mental Behavioral and Neurodevelopmental disor...
# 119  Mental Behavioral and Neurodevelopmental disor...
# 120  Mental Behavioral and Neurodevelopmental disor...
# 121  Mental Behavioral and Neurodevelopmental disor...
# 122  Mental Behavioral and Neurodevelopmental disor...
# 123  Mental Behavioral and Neurodevelopmental disor...
# 124  Mental Behavioral and Neurodevelopmental disor...
# 125  Mental Behavioral and Neurodevelopmental disor...
# 126  Mental Behavioral and Neurodevelopmental disor...
# 127  Mental Behavioral and Neurodevelopmental disor...
# 128  Mental Behavioral and Neurodevelopmental disor...
# 129                     Diseases of the nervous system
# 130  Mental Behavioral and Neurodevelopmental disor...
# 131  Mental Behavioral and Neurodevelopmental disor...
# 132  Mental Behavioral and Neurodevelopmental disor...
# 133  Mental Behavioral and Neurodevelopmental disor...
# 134  Mental Behavioral and Neurodevelopmental disor...
# 135  Mental Behavioral and Neurodevelopmental disor...
# 136  Mental Behavioral and Neurodevelopmental disor...
# 137  Mental Behavioral and Neurodevelopmental disor...
# 138  Mental Behavioral and Neurodevelopmental disor...
# 139  Mental Behavioral and Neurodevelopmental disor...
# 140  Mental Behavioral and Neurodevelopmental disor...
#
#                                                   cat5  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    Mental disorders due to known physiological co...
# 5    Mental disorders due to known physiological co...
# 6    Mental disorders due to known physiological co...
# 7    Mental and behavioral disorders due to psychoa...
# 8    Mental and behavioral disorders due to psychoa...
# 9    Mental and behavioral disorders due to psychoa...
# 10   Mental and behavioral disorders due to psychoa...
# 11   Mental and behavioral disorders due to psychoa...
# 12                         Anxiety dissociative stress
# 13   Other degenerative diseases of the nervous system
# 14   Mental and behavioral disorders due to psychoa...
# 15   Mental and behavioral disorders due to psychoa...
# 16   Mental and behavioral disorders due to psychoa...
# 17                          Mood [affective] disorders
# 18   Mental and behavioral disorders due to psychoa...
# 19   Mental and behavioral disorders due to psychoa...
# 20   Mental and behavioral disorders due to psychoa...
# 21   Mental and behavioral disorders due to psychoa...
# 22                          Mood [affective] disorders
# 23   Mental and behavioral disorders due to psychoa...
# 24   Mental and behavioral disorders due to psychoa...
# 25   Mental and behavioral disorders due to psychoa...
# 26                          Mood [affective] disorders
# 27   Mental and behavioral disorders due to psychoa...
# 28   Mental disorders due to known physiological co...
# 29   Mental and behavioral disorders due to psychoa...
# ..                                                 ...
# 111  Mental disorders due to known physiological co...
# 112  Mental disorders due to known physiological co...
# 113  Mental and behavioral disorders due to psychoa...
# 114  Mental and behavioral disorders due to psychoa...
# 115  Mental and behavioral disorders due to psychoa...
# 116  Mental and behavioral disorders due to psychoa...
# 117  Mental and behavioral disorders due to psychoa...
# 118                         Mood [affective] disorders
# 119  Mental and behavioral disorders due to psychoa...
# 120  Mental and behavioral disorders due to psychoa...
# 121                         Mood [affective] disorders
# 122                         Mood [affective] disorders
# 123                         Mood [affective] disorders
# 124  Mental and behavioral disorders due to psychoa...
# 125  Mental and behavioral disorders due to psychoa...
# 126                         Mood [affective] disorders
# 127  Mental and behavioral disorders due to psychoa...
# 128                         Mood [affective] disorders
# 129  Other degenerative diseases of the nervous system
# 130  Mental and behavioral disorders due to psychoa...
# 131  Mental disorders due to known physiological co...
# 132  Mental and behavioral disorders due to psychoa...
# 133  Mental and behavioral disorders due to psychoa...
# 134  Mental and behavioral disorders due to psychoa...
# 135  Mental and behavioral disorders due to psychoa...
# 136                         Mood [affective] disorders
# 137                         Mood [affective] disorders
# 138  Mental disorders due to known physiological co...
# 139        Disorders of adult personality and behavior
# 140                         Mood [affective] disorders
#
#                                                   cat6    type   value  \
# 0                                                 None  icd_10    F200
# 1                                                 None   icd_9   29530
# 2                                                 None  icd_10    F205
# 3                                                 None   icd_9  No map
# 4                                    Vascular dementia  icd_10   F0150
# 5                                 Unspecified dementia  icd_10    F039
# 6                                 Unspecified dementia  icd_10   F0390
# 7                            Alcohol related disorders  icd_10  F10150
# 8                             Opioid related disorders  icd_10  F11120
# 9                             Opioid related disorders  icd_10  F11122
# 10      Other psychoactive substance related disorders  icd_10   F1917
# 11      Other psychoactive substance related disorders  icd_10   F1927
# 12                       Obsessive-compulsive disorder  icd_10     F42
# 13     Oth degenerative diseases of nervous system NEC  icd_10   G3109
# 14                           Alcohol related disorders  icd_10   F1011
# 15                            Opioid related disorders  icd_10  F11181
# 16                            Opioid related disorders  icd_10  F11188
# 17                 Major depressive disorder recurrent  icd_10    F330
# 18                           Alcohol related disorders  icd_10   F1097
# 19                           Alcohol related disorders  icd_10   F1018
# 20                            Opioid related disorders  icd_10   F1112
# 21                            Opioid related disorders  icd_10  F11129
# 22                 Major depressive disorder recurrent  icd_10    F338
# 23                           Alcohol related disorders  icd_10   F1012
# 24                           Alcohol related disorders  icd_10  F10151
# 25                            Opioid related disorders  icd_10   F1119
# 26                 Major depressive disorder recurrent  icd_10   F3341
# 27   Sedative hypnotic or anxiolytic related disorders  icd_10   F1327
# 28     Dementia in other diseases classified elsewhere   icd_9   29410
# 29                           Alcohol related disorders   icd_9    2912
# ..                                                 ...     ...     ...
# 111                                  Vascular dementia  icd_10   F0151
# 112    Dementia in other diseases classified elsewhere  icd_10    F028
# 113                          Alcohol related disorders  icd_10  F10182
# 114                          Alcohol related disorders  icd_10  F10188
# 115                          Alcohol related disorders  icd_10   F1027
# 116                           Opioid related disorders  icd_10    F111
# 117     Other psychoactive substance related disorders  icd_10   F1997
# 118                Major depressive disorder recurrent  icd_10   F3340
# 119                          Alcohol related disorders  icd_10   F1014
# 120                          Alcohol related disorders  icd_10  F10180
# 121           Major depressive disorder single episode  icd_10    F321
# 122                Major depressive disorder recurrent  icd_10   F3342
# 123                Major depressive disorder recurrent  icd_10    F333
# 124                           Opioid related disorders  icd_10  F11159
# 125  Sedative hypnotic or anxiolytic related disorders  icd_10   F1397
# 126                Major depressive disorder recurrent  icd_10     F33
# 127                         Inhalant related disorders  icd_10   F1897
# 128                Major depressive disorder recurrent  icd_10    F331
# 129    Oth degenerative diseases of nervous system NEC  icd_10    G310
# 130                          Alcohol related disorders  icd_10   F1019
# 131                                  Vascular dementia   icd_9   29041
# 132                          Alcohol related disorders   icd_9   30500
# 133                          Alcohol related disorders   icd_9   29182
# 134                           Opioid related disorders   icd_9   29289
# 135                           Opioid related disorders   icd_9   29285
# 136           Major depressive disorder single episode   icd_9   29620
# 137                Major depressive disorder recurrent   icd_9   29630
# 138                               Unspecified dementia   icd_9    2900
# 139                     Specific personality disorders   icd_9    3014
# 140           Major depressive disorder single episode   icd_9   29624
#
#                                            description active_date  \
# 0                               Paranoid schizophrenia  2018-08-28
# 1              Paranoid type schizophrenia unspecified  2018-08-28
# 2                               Residual schizophrenia  2018-08-28
# 3                                               No map  2018-08-28
# 4     Vascular dementia without behavioral disturbance  2018-08-28
# 5                                 Unspecified dementia  2018-08-28
# 6    Unspecified dementia without behavioral distur...  2018-08-28
# 7    Alcohol abuse with alcohol-induced psychotic d...  2018-08-28
# 8         Opioid abuse with intoxication uncomplicated  2018-08-28
# 9    Opioid abuse with intoxication with perceptual...  2018-08-28
# 10   Other psychoactive substance abuse with psycho...  2018-08-28
# 11   Other psychoactive substance dependence with p...  2018-08-28
# 12                       Obsessive-compulsive disorder  2018-08-28
# 13                       Other frontotemporal dementia  2018-08-28
# 14                          Alcohol abuse in remission  2018-08-28
# 15   Opioid abuse with opioid-induced sexual dysfun...  2018-08-28
# 16     Opioid abuse with other opioid-induced disorder  2018-08-28
# 17            Major depressive disorder recurrent mild  2018-08-28
# 18   Alcohol use unspecified with alcohol-induced p...  2018-08-28
# 19   Alcohol abuse with other alcohol-induced disor...  2018-08-28
# 20                      Opioid abuse with intoxication  2018-08-28
# 21          Opioid abuse with intoxication unspecified  2018-08-28
# 22                Other recurrent depressive disorders  2018-08-28
# 23                     Alcohol abuse with intoxication  2018-08-28
# 24   Alcohol abuse with alcohol-induced psychotic d...  2018-08-28
# 25   Opioid abuse with unspecified opioid-induced d...  2018-08-28
# 26   Major depressive disorder recurrent in partial...  2018-08-28
# 27   Sedative hypnotic or anxiolytic dependence wit...  2018-08-28
# 28   Dementia in conditions classified elsewhere wi...  2018-08-28
# 29                 Alcohol-induced persisting dementia  2018-08-28
# ..                                                 ...         ...
# 111      Vascular dementia with behavioral disturbance  2018-08-28
# 112    Dementia in other diseases classified elsewhere  2018-08-28
# 113  Alcohol abuse with alcohol-induced sleep disorder  2018-08-28
# 114  Alcohol abuse with other alcohol-induced disorder  2018-08-28
# 115  Alcohol dependence with alcohol-induced persis...  2018-08-28
# 116                                       Opioid abuse  2018-08-28
# 117  Other psychoactive substance use unspecified w...  2018-08-28
# 118  Major depressive disorder recurrent in remissi...  2018-08-28
# 119   Alcohol abuse with alcohol-induced mood disorder  2018-08-28
# 120  Alcohol abuse with alcohol-induced anxiety dis...  2018-08-28
# 121  Major depressive disorder single episode moderate  2018-08-28
# 122  Major depressive disorder recurrent in full re...  2018-08-28
# 123  Major depressive disorder recurrent severe wit...  2018-08-28
# 124  Opioid abuse with opioid-induced psychotic dis...  2018-08-28
# 125  Sedative hypnotic or anxiolytic use unspecifie...  2018-08-28
# 126                Major depressive disorder recurrent  2018-08-28
# 127  Inhalant use unspecified with inhalant-induced...  2018-08-28
# 128       Major depressive disorder recurrent moderate  2018-08-28
# 129                            Frontotemporal dementia  2018-08-28
# 130  Alcohol abuse with unspecified alcohol-induced...  2018-08-28
# 131                    Vascular dementia with delirium  2018-08-28
# 132                          Alcohol abuse unspecified  2018-08-28
# 133                    Alcohol induced sleep disorders  2018-08-28
# 134      Other specified drug-induced mental disorders  2018-08-28
# 135                       Drug induced sleep disorders  2018-08-28
# 136  Major depressive affective disorder single epi...  2018-08-28
# 137  Major depressive affective disorder recurrent ...  2018-08-28
# 138                      Senile dementia uncomplicated  2018-08-28
# 139          Obsessive-compulsive personality disorder  2018-08-28
# 140  Major depressive affective disorder single epi...  2018-08-28
#
#     active_reason deactive_date deactive_reason                  source
# 0            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 1            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 2            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 3            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 4            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 5            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 6            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 7            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 8            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 9            Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 10           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 11           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 12           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 13           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 14           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 15           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 16           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 17           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 18           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 19           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 20           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 21           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 22           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 23           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 24           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 25           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 26           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 27           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 28           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 29           Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# ..            ...           ...             ...                     ...
# 111          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 112          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 113          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 114          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 115          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 116          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 117          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 118          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 119          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 120          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 121          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 122          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 123          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 124          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 125          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 126          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 127          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 128          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 129          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 130          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 131          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 132          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 133          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 134          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 135          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 136          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 137          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 138          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 139          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
# 140          Nish          None            None  RWD_DB.RWD.ICD_GROUPER
#
# [141 rows x 14 columns]

# %% [markdown]
# ## Check

# %%
# Export to check, and then will inactivate codes that are not relevant and re-upload as final reference table
df.to_excel("out/comorbidities_check.xlsx", index=False)

# %% [markdown]
# ## Upload into snowflake

# %%
scz_ref = pd.read_excel("in/ref.xlsx")

# %%
snow.drop_table("st_scz_ref")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_scz_ref;
# Table sandbox.st_scz_ref dropped!

# %%
snow.upload_dataframe(scz_ref, "st_scz_ref")
# Out:
# Upload successful!

# %%
# %%read_sql
#
# select *
# from st_scz_ref
# where deactive_date is not null
# Out:
# Query started at 02:33:53 PM India Standard Time; Query executed in 0.07 m
#    cat1         cat2           cat3  \
# 0    dx  comorbidity       dementia
# 1    dx  comorbidity       dementia
# 2    dx  comorbidity       dementia
# 3    dx  comorbidity       dementia
# 4    dx  comorbidity       dementia
# 5    dx  comorbidity       dementia
# 6    dx  comorbidity       dementia
# 7    dx  comorbidity       dementia
# 8    dx  comorbidity  alcohol abuse
# 9    dx  comorbidity       dementia
# 10   dx  comorbidity  alcohol abuse
# 11   dx  comorbidity     depression
# 12   dx  comorbidity  alcohol abuse
# 13   dx  comorbidity            OCD
# 14   dx  comorbidity  alcohol abuse
# 15   dx  comorbidity  alcohol abuse
# 16   dx  comorbidity       dementia
# 17   dx  comorbidity       dementia
# 18   dx  comorbidity       dementia
# 19   dx  comorbidity       dementia
# 20   dx  comorbidity       dementia
# 21   dx  comorbidity       dementia
# 22   dx  comorbidity  alcohol abuse
# 23   dx  comorbidity   opioid abuse
# 24   dx  comorbidity   opioid abuse
# 25   dx  comorbidity            OCD
#
#                                                  cat4  \
# 0   Mental Behavioral and Neurodevelopmental disor...
# 1   Mental Behavioral and Neurodevelopmental disor...
# 2                      Diseases of the nervous system
# 3   Mental Behavioral and Neurodevelopmental disor...
# 4   Mental Behavioral and Neurodevelopmental disor...
# 5   Mental Behavioral and Neurodevelopmental disor...
# 6   Mental Behavioral and Neurodevelopmental disor...
# 7   Mental Behavioral and Neurodevelopmental disor...
# 8   Factors influencing health status and contact ...
# 9   Mental Behavioral and Neurodevelopmental disor...
# 10  Factors influencing health status and contact ...
# 11  Mental Behavioral and Neurodevelopmental disor...
# 12  Factors influencing health status and contact ...
# 13  Mental Behavioral and Neurodevelopmental disor...
# 14  Mental Behavioral and Neurodevelopmental disor...
# 15  Factors influencing health status and contact ...
# 16                     Diseases of the nervous system
# 17  Mental Behavioral and Neurodevelopmental disor...
# 18  Mental Behavioral and Neurodevelopmental disor...
# 19  Mental Behavioral and Neurodevelopmental disor...
# 20  Mental Behavioral and Neurodevelopmental disor...
# 21                     Diseases of the nervous system
# 22  Mental Behavioral and Neurodevelopmental disor...
# 23  Mental Behavioral and Neurodevelopmental disor...
# 24  Mental Behavioral and Neurodevelopmental disor...
# 25  Mental Behavioral and Neurodevelopmental disor...
#
#                                                  cat5  \
# 0   Mental and behavioral disorders due to psychoa...
# 1   Mental and behavioral disorders due to psychoa...
# 2   Other degenerative diseases of the nervous system
# 3   Mental and behavioral disorders due to psychoa...
# 4   Mental and behavioral disorders due to psychoa...
# 5   Mental and behavioral disorders due to psychoa...
# 6   Mental and behavioral disorders due to psychoa...
# 7   Mental and behavioral disorders due to psychoa...
# 8   Persons with potential health hazards related ...
# 9   Mental and behavioral disorders due to psychoa...
# 10  Persons encountering health services in other ...
# 11  Schizophrenia schizotypal delusional and other...
# 12  Persons encountering health services in other ...
# 13        Disorders of adult personality and behavior
# 14  Mental and behavioral disorders due to psychoa...
# 15  Persons encountering health services in other ...
# 16  Other degenerative diseases of the nervous system
# 17  Mental and behavioral disorders due to psychoa...
# 18  Mental and behavioral disorders due to psychoa...
# 19  Mental and behavioral disorders due to psychoa...
# 20  Mental and behavioral disorders due to psychoa...
# 21  Other degenerative diseases of the nervous system
# 22  Mental and behavioral disorders due to psychoa...
# 23  Mental and behavioral disorders due to psychoa...
# 24  Mental and behavioral disorders due to psychoa...
# 25        Disorders of adult personality and behavior
#
#                                                  cat6    type  value  \
# 0      Other psychoactive substance related disorders  icd_10  F1917
# 1      Other psychoactive substance related disorders  icd_10  F1927
# 2     Oth degenerative diseases of nervous system NEC  icd_10  G3109
# 3                           Alcohol related disorders  icd_10  F1097
# 4   Sedative hypnotic or anxiolytic related disorders  icd_10  F1327
# 5                           Alcohol related disorders   icd_9   2912
# 6      Other psychoactive substance related disorders   icd_9  29282
# 7                          Inhalant related disorders  icd_10  F1817
# 8   Family history of mental and behavioral disorders  icd_10   Z811
# 9                          Inhalant related disorders  icd_10  F1827
# 10  Persons encntr health serv for oth cnsl and me...  icd_10  Z7141
# 11                          Schizoaffective disorders  icd_10   F251
# 12  Persons encntr health serv for oth cnsl and me...  icd_10   Z714
# 13                     Specific personality disorders  icd_10   F605
# 14                          Alcohol related disorders   icd_9  29189
# 15  Persons encntr health serv for oth cnsl and me...   icd_9  V6542
# 16    Oth degenerative diseases of nervous system NEC   icd_9  33119
# 17                          Alcohol related disorders  icd_10  F1027
# 18     Other psychoactive substance related disorders  icd_10  F1997
# 19  Sedative hypnotic or anxiolytic related disorders  icd_10  F1397
# 20                         Inhalant related disorders  icd_10  F1897
# 21    Oth degenerative diseases of nervous system NEC  icd_10   G310
# 22                          Alcohol related disorders   icd_9  29182
# 23                           Opioid related disorders   icd_9  29289
# 24                           Opioid related disorders   icd_9  29285
# 25                     Specific personality disorders   icd_9   3014
#
#                                           description active_date  \
# 0   Other psychoactive substance abuse with psycho...  2018-08-28
# 1   Other psychoactive substance dependence with p...  2018-08-28
# 2                       Other frontotemporal dementia  2018-08-28
# 3   Alcohol use unspecified with alcohol-induced p...  2018-08-28
# 4   Sedative hypnotic or anxiolytic dependence wit...  2018-08-28
# 5                 Alcohol-induced persisting dementia  2018-08-28
# 6                    Drug-induced persisting dementia  2018-08-28
# 7       Inhalant abuse with inhalant-induced dementia  2018-08-28
# 8      Family history of alcohol abuse and dependence  2018-08-28
# 9   Inhalant dependence with inhalant-induced deme...  2018-08-28
# 10  Alcohol abuse counseling and surveillance of a...  2018-08-28
# 11           Schizoaffective disorder depressive type  2018-08-28
# 12          Alcohol abuse counseling and surveillance  2018-08-28
# 13          Obsessive-compulsive personality disorder  2018-08-28
# 14             Other alcohol-induced mental disorders  2018-08-28
# 15              Counseling on substance use and abuse  2018-08-28
# 16                      Other frontotemporal dementia  2018-08-28
# 17  Alcohol dependence with alcohol-induced persis...  2018-08-28
# 18  Other psychoactive substance use unspecified w...  2018-08-28
# 19  Sedative hypnotic or anxiolytic use unspecifie...  2018-08-28
# 20  Inhalant use unspecified with inhalant-induced...  2018-08-28
# 21                            Frontotemporal dementia  2018-08-28
# 22                    Alcohol induced sleep disorders  2018-08-28
# 23      Other specified drug-induced mental disorders  2018-08-28
# 24                       Drug induced sleep disorders  2018-08-28
# 25          Obsessive-compulsive personality disorder  2018-08-28
#
#    active_reason deactive_date             deactive_reason  \
# 0           Nish     28-8-2018       not strictly dementia
# 1           Nish     28-8-2018       not strictly dementia
# 2           Nish     28-8-2018       not strictly dementia
# 3           Nish     28-8-2018       not strictly dementia
# 4           Nish     28-8-2018       not strictly dementia
# 5           Nish     28-8-2018       not strictly dementia
# 6           Nish     28-8-2018       not strictly dementia
# 7           Nish     28-8-2018       not strictly dementia
# 8           Nish     28-8-2018  not strictly alcohol abuse
# 9           Nish     28-8-2018       not strictly dementia
# 10          Nish     28-8-2018  not strictly alcohol abuse
# 11          Nish     28-8-2018       sczaffective disorder
# 12          Nish     28-8-2018  not strictly alcohol abuse
# 13          Nish     28-8-2018            not strictly OCD
# 14          Nish     28-8-2018  not strictly alcohol abuse
# 15          Nish     28-8-2018  not strictly alcohol abuse
# 16          Nish     28-8-2018       not strictly dementia
# 17          Nish     28-8-2018       not strictly dementia
# 18          Nish     28-8-2018       not strictly dementia
# 19          Nish     28-8-2018       not strictly dementia
# 20          Nish     28-8-2018       not strictly dementia
# 21          Nish     28-8-2018       not strictly dementia
# 22          Nish     28-8-2018  not strictly alcohol abuse
# 23          Nish     28-8-2018            not opioid abuse
# 24          Nish     28-8-2018            not opioid abuse
# 25          Nish     28-8-2018            not strictly OCD
#
#                     source
# 0   RWD_DB.RWD.ICD_GROUPER
# 1   RWD_DB.RWD.ICD_GROUPER
# 2   RWD_DB.RWD.ICD_GROUPER
# 3   RWD_DB.RWD.ICD_GROUPER
# 4   RWD_DB.RWD.ICD_GROUPER
# 5   RWD_DB.RWD.ICD_GROUPER
# 6   RWD_DB.RWD.ICD_GROUPER
# 7   RWD_DB.RWD.ICD_GROUPER
# 8   RWD_DB.RWD.ICD_GROUPER
# 9   RWD_DB.RWD.ICD_GROUPER
# 10  RWD_DB.RWD.ICD_GROUPER
# 11  RWD_DB.RWD.ICD_GROUPER
# 12  RWD_DB.RWD.ICD_GROUPER
# 13  RWD_DB.RWD.ICD_GROUPER
# 14  RWD_DB.RWD.ICD_GROUPER
# 15  RWD_DB.RWD.ICD_GROUPER
# 16  RWD_DB.RWD.ICD_GROUPER
# 17  RWD_DB.RWD.ICD_GROUPER
# 18  RWD_DB.RWD.ICD_GROUPER
# 19  RWD_DB.RWD.ICD_GROUPER
# 20  RWD_DB.RWD.ICD_GROUPER
# 21  RWD_DB.RWD.ICD_GROUPER
# 22  RWD_DB.RWD.ICD_GROUPER
# 23  RWD_DB.RWD.ICD_GROUPER
# 24  RWD_DB.RWD.ICD_GROUPER
# 25  RWD_DB.RWD.ICD_GROUPER

# %% [markdown]
# # Cohort in obs. window
#
# <img src="in/cohort2.png", width=700>

# %%
# %%read_sql
# create or replace table st_scz_comorb1 as
#
# select
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
#     claim_number,
#     diagnosis,
#     diagnosis_sequence,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
#
#     where left (diagnosis,3) in ('F20')
#     and left(patient_id, 5) != 'XXX -'
#     limit 1000
# Out:
# Query started at 07:53:26 PM India Standard Time; Query executed in 0.17 m
#                                        status
# 0  Table ST_SCZ_COMORB1 successfully created.

# %%
snow.select("select * from RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS where left (diagnosis,3) in ('F20') limit 100")
# Out:
#              claim_number                               encrypted_key_1  \
# 0   con_EP022216736773510  Gz1NV4yRXli2AlrLfDKY9gTHfU1ehN/TRKjSLF2KBdI=
# 1   con_EP032018702143506  0TwXRDHGvgE8wvBmuLuuSZoB4gY+e4CZLDOn+V4Jh1k=
# 2   con_EP021816728464918  sDbzrfH7wAugsmZpp6ct6GK1aX+i+0RC4ivg34AoJ/A=
# 3   con_EI020216271933848  0l+4xmG/aoI/z/9UKV/owMq2jHI+u9UXW2+E9BNrOfY=
# 4   con_EI012616247786247  6PwNFHwm3Lv3t6erFkKrKf9rvJuwCl2UiilNg+VSm/Y=
# 5   con_EP012816758905938  Xc1JrzMJE89zK/P3LMZ7/n7fgDucwkHkC/phpIlpoX8=
# 6   con_EP021316711150167  8r0E3CEsL1zzbBQ6bBp7rxr35b8RRWHvu6GkSCxfgb4=
# 7   con_EP020616788665608  HunV5XDehtKXa5MEqrD70vmTuDivdZNLxgJnCjfnQrA=
# 8   con_EI012216238015400  67FwMLnsSVtXbJMN1LfwiyPP32PhENU9McZm4LZj8yc=
# 9   con_EP041216706519066  oCxpoM3p3lQWUWwRgwJFgIHnXjVokusBPzpLrZt83ow=
# 10  con_EI020216272094428  PFakhdH5xJ4EyVftnuS5GLUCvcp/Si7F9L4ceNIMWmk=
# 11  con_EP012016728764884  GAa+gkxjx8VB2PvUvnNwfksOFnzPAae9xAsf2DJ2eig=
# 12  con_EP020416781192674  EVGkTjaDAM8oaJx+Rx7HtwgAqhqDGV26XS5y4cnxKxc=
# 13  con_EI020116269741078  DJOU7SITOj2wnd+o5S2MLTNU5NnpYH0aOQShhnGYuR8=
# 14  con_EI012916261243839  yDL+qQLtN8WyJqGi5v7tq0FQy7aubvB7ygzsXe2bU0o=
# 15  con_EP040416782017138  sk8E+G/rBZtV3Cc+aIK337WbY/9B0vUwZMiS+cm+/J8=
# 16  con_EI020216274259605  EMfVsTz/7rYwOVGir0ReCeOD6sttMfngRITFPNjFo0I=
# 17  con_EP020916797526793  rhv2sCoCiBhn12piDXFnI0eSbw5UR/rZhGcmgVlLT2w=
# 18         alb_1333525197  qP/op22GvoExS3V/4zbabx9NZr1Lr0fspzAtXNG71TQ=
# 19  con_EP022416746250693  ZT7/npU9P63PKBvmWR5MwFzopnyH5SBJMWyjWp4BGiQ=
# 20  con_EP060216782601935  mN+4YkpnIkhQRYJdcPHa+Eof6PWe1PkT5vm0I04b04o=
# 21  con_EP032216737842752  /q49rYLegs8Aj0hIG6FPBxY0cOtpH1GpMb3BDNOicYc=
# 22  con_EI022716257454593  jeEfsMqAXp35C5D2oWpKbYNvd+f8am0Zsc4Fjarc4C0=
# 23  con_EP020816792792626  FOLyTb8bCIVUDiKZnx+v3zoVUXVOobvKdZdm8IlCtBA=
# 24         alb_1371881044  H2bewDTakzUENsQDkLtgFJOG3frV1lb/5ryy2JgIAmQ=
# 25  con_EI012916264175508  29zJV9dw5+eAyCnEmAXulefdgRt6pqS5bgBgm0A4N7o=
# 26  con_EP061516723000259  qOGn3bspXbytoT6Q81ZmGva19KGhiZOLALiSKavBjJ0=
# 27  con_EP021216709362513  yLj4GaZp7h5noMBlNPalfEUM+LsgmnnMxAO3IpNkks0=
# 28  con_EI052316246964864  c5v2m4E713G8WeNrGA0kDkYBhhLxMMNzuwpEB6mSZss=
# 29  con_EI012216240052379  SYoOZpSEkDnv93Y+jJmBuf0OxggmUSs1qZJmZRdmCl0=
# ..                    ...                                           ...
# 70  con_EP022516751681271  N1Fv2NWDz55WI3Z/wcyRKHyu1xcGIdlK/Dq4MJ2neAw=
# 71  con_EI020216271950931  sghIKrae1vM93Vi/bqjKvI0NsUwCw0dH5l4aNroYOfc=
# 72  con_EP012916763870788  tYOKNXgFyVbgbkdlJ57J969lC8UHgG8dxIU4wmdkhqY=
# 73  con_EP081518741146820  inDoz9Vs8WiGeMYl91ui+UUl/C8SVuXv/87OtdEinKQ=
# 74  con_EP081418737000411  cXnYeqAFoycfdE/L2SWZ7IdKWeyRmT2vKcjMwachOZw=
# 75  con_EP081518741183866  s4JPEi0krOxgUco57hjhgOKozX9FhNpTqUjQsKHQrpI=
# 76  con_EI081518241005899  XND8IvnmXa8jAWlBFXD5gH0VhH5xEQ3bIfJYhpkZoP8=
# 77  con_EP081518739659744  aNsjiLFNGi/nt6RFVHuhPKBXCT37mfLB5HAUvoUz8B0=
# 78  con_EP081518741135661  5J2XaR+9NLryri1i0+5gM44xhA3MutvnkkB3jRbG/aM=
# 79  con_EP081518738919846  jau0qOxEZDDnrEq3l7735mDIjjbXCqtGnB/RQxKP0W4=
# 80  con_EI081518241063367  lHh27TlayT7KSmNudD+L513UnDbo/XdMU1YVfCPCw6U=
# 81  con_EP081418737233266  j6RFgcwmhPq4pVZHRwE1YPHwp+vbqD9t/j/7lnFStYU=
# 82  con_EI081518239204792  1cAAQZH8IbzG1EbJVnkMJ0b3gTmDLE6UhWdigTwX4GQ=
# 83  con_EP081518738919844  jau0qOxEZDDnrEq3l7735mDIjjbXCqtGnB/RQxKP0W4=
# 84  con_EP081518739527145  UdWC55QTjcnQ5QLSNYj5SlaY0xtyprQVr8fAdLZ/Gfg=
# 85  con_EP081518741071277  1RWUomh8UPWUozOvj1TRUr6jOhPliaB639f9ZBKrSGg=
# 86  con_EP081518740037641  j7gpRoKIN5nVvOg0a+9GUGQDfO1iURXrnKTd6jKS5pY=
# 87  con_EP081518739927767  ognPYE/uRr5Uq9tfnBb+7gL8ECQWRbrlMld4xKunLs8=
# 88  con_EP081518739660180  hjpekqEElfAuUZx4jO4acdZ8J5UirhE+x8vDh9XZNd4=
# 89  con_EP081518739614514  3Xhmulm38NIRHnvR6kzCpLrJsSvGDqdi+8ug/XC/MJQ=
# 90  con_EP081518740033153  LabRJwqJuloXlfXONeanDYBQ3/jhDenY7cubVRIXg1c=
# 91  con_EP081518738160721  sfE3+Uh5Bod8JMXgdO24upSJ5qGysPMoTkAZVZZ3NvQ=
# 92  con_EI081518240387383  8QxcJaciMNBOERgKm6wl5KTJwXI3ew6wdWQusWlxUMA=
# 93  con_EP081518737447408  ST/ViB1hhulxGtXKCZWakqrfssLb3JMCBCl1DD1uKfY=
# 94  con_EP081518740077847  TwTD/BUpu2K6uU938ONV1AOuLTlkpx7u1kwtFNy7FxQ=
# 95  con_EI081518240370124  JJgRGJTavreJ5rE8YjiQzOWHRxGganbTpUW3z1KVFxk=
# 96  con_EP081518740077559  waP70e8PQR0NRtsrdK72xafNAEdfJUH7W2bTbXfKsFo=
# 97  con_EI081518239011092  skUXu5M8pjno3F3Vk5MMbB2Be2RFIMw7H1HxXzw3wBg=
# 98  con_EP081518737589748  VNno12ZpI/lXcpkicAdc+ZZyt0ViYwetoXZpxOa3IRo=
# 99  con_EP081518738958216  PEpe/Jf7Hn0/QbKZPIDGIUldd/7zSZ+a+AAs6dEDvnk=
#
#                                  encrypted_key_2 code_type diagnosis  \
# 0   aDHPPBxB8DSM6vEmXKHmCmjc20EWMiOGvM5KH6JAnsA=     ICD10      F209
# 1   1tWHjQQLDxqaVFSoxPkW5m58pLRA/0KhviRLlNKJvRA=     ICD10      F209
# 2   oiCJP5EZFsLLe/VCWWlPV0zT8koQek/+TyEC7cKgc8E=     ICD10      F209
# 3   LTtPVOPf0HZWgfpf1fMn9ZRCcW7bwd8sNPRMrFYiSfE=     ICD10      F209
# 4   +qwOWFDkZCCIdVulDv3POnPoW+957oYecBxi0Ugth+g=     ICD10      F209
# 5   waDIDfJvBwDTlYXoyehHPsHr2uMvYwYOGyet92Zc+kU=     ICD10      F209
# 6   CN6IbhuVdINFl/pK1JpTDBiVX5eVCL90q5hqA8vmAtw=     ICD10      F209
# 7   piHRqBBGnBJhotWfHQqOkv9kUx9OlB6byYXrvUhAL58=     ICD10      F209
# 8   HP1JU1Q2vm6PR0FDvGY+1z1hhWUJGSRHrCUuVAAmvVs=     ICD10      F209
# 9   /aEgQZJ8Z+NednKzbwJR/qWqS8QhhxybcnftkZeYvo4=     ICD10      F209
# 10  1TcMNdKPwxmjkBuXsHBhISVn9pzMrGluIyv8IZxrrhU=     ICD10      F209
# 11  7r47mpeSfHDIzgxO0tVYsNt+Io+hanH/ZAOFHr777yI=     ICD10      F209
# 12  SNpFIltEICw31bEp9g6s2a3NQk4msmTc1Jit5X41OOU=     ICD10      F209
# 13  RVUz/oLS7ON7VkDfm12Vp2wLP7tyo/GIfoXU7qey6bg=     ICD10      F209
# 14  f8d2G4/FYNrJN3nxD5oWDWkdAcEdXoUvegJpd9P9mxk=     ICD10      F209
# 15  Nz3ip8COURH4PjqiDV2iaO7mwhiR5uND20L+rrq6J+k=     ICD10      F209
# 16  0p8KHMmibatNMYKG0y6Voqtt8P5RuahgfOD8n8iJ4eA=     ICD10      F209
# 17  WlMS4ircDb1T7toIq62GZvWnmpJPmiTQTUHCIl3LJXQ=     ICD10      F209
# 18  hE7/55Nc2im0XrzpU/uNqEFFCu1yNFqyvdigFTuPnL4=     ICD10      F209
# 19  b1NGeh1kFe/42Hu68nSaRZPoTydSakrIoCtorK6kKTg=     ICD10      F209
# 20  xQ0ztiDUeNVb4JVi5JJm0leUOby8j5FGGuptKcDYZTc=     ICD10      F209
# 21  JKMwdI/t1QiALgNy/WhZZbREwLBrk8/AGdz4ON3ufWY=     ICD10      F209
# 22  TydyyaqixzIcZtNFBmgb8WnZnyNvW1kalpTJ8+YTY9E=     ICD10      F209
# 23  GhlqUgohr0hcUdrWqCVFygLtklZMbs2kn1fCoBQOox4=     ICD10      F209
# 24  k0HOje6kVU84VePdT8iuHNPSXasr+UU+V2emRA930HI=     ICD10      F209
# 25  LfLBemdgqWxxAtQpNjn4BnGd8ZjrANn1DIJpO9eszUc=     ICD10      F209
# 26  vrlBkJDEcyKhGXAHoTdz8LvmMeS47Juqfe95w1t6038=     ICD10      F209
# 27  I3yiC5x1UREv+REIUzEMxyUxyaQy0sZ9jTIMZEEpBlw=     ICD10      F209
# 28  MbG+R58u13+uWM2p2ZHUmvo7+/lSDxX9ZF+RpBKeabg=     ICD10      F209
# 29  WvFALP3Quotr8pKQ6GTeT2MKURMEqm2Vc7yLmUi2+K4=     ICD10      F209
# ..                                           ...       ...       ...
# 70  MsgvI2xr3yx4HsM5rl+pgPAlRpfbiVYrYAUgk84ArMg=     ICD10      F209
# 71  IoABdE4GmJARwpffzpEMANgFCf/QizgmX2AGbzTOi6k=     ICD10      F209
# 72  db4JMWQOgOp8cTwhJRp7JNdVhrokk1lCw2RJC4yuJXQ=     ICD10      F209
# 73  w21MQazKzI1Efk/jSWMeOvgoQs1phkbwjuunXt3AQpQ=     ICD10      F209
# 74  jW2bW4L2L4fblj0htUQuQBpT7+9/tgGjBQTzrVP+iOw=     ICD10      F209
# 75  nie215R0x4Jv+UdTXiljgrhPGiibIxGBv41YbJ+Murs=     ICD10      F205
# 76  pp+XpTnABylTvmIWY+lnA3LwzcxNNpVWHAxC6Q0lzQQ=     ICD10      F200
# 77  +9BCFTQvLm+OAmGKPGqfkEZvEXs/Wifmhi3g8AZX4kc=     ICD10      F209
# 78  lmKnKNPz40yNkwfnJfKf2sFNDEOcjsxMMqxoKjvEhIw=     ICD10      F209
# 79  +lix3AdeREg/+lmyPQJ2v7BptV3iYsthnkG5UR5h2HQ=     ICD10      F209
# 80  kLZu/rAkteQv9ExD7R325C+GDleeEYQWH9OPFsTDYvU=     ICD10      F200
# 81  SClzdUjHWoIoPVYafO+lXsrxovzSDK3rlPuvPEuUpT4=     ICD10     F2089
# 82  FZ1gBpL/XzbLM4cAH0+UsXQJtfoRk0UhVtANwapJ20I=     ICD10      F209
# 83  +lix3AdeREg/+lmyPQJ2v7BptV3iYsthnkG5UR5h2HQ=     ICD10      F209
# 84  W1IdBepWq0FwLjS7tn9uSA3nt6zWLO5pJwoi1T4boLc=     ICD10      F200
# 85  NfFxVFwDatnv87bL5D1CIpDe0AV8GkUORrPPa0MTMlE=     ICD10      F209
# 86  ymbUyjPOGwvZ9LrNpID75ZoFvQ2Orb3d/zjZOJj/28Y=     ICD10      F200
# 87  oecWvo8VCnBhQzSBL0Y9/5wzl4ljYicRYx39kp2Dl1M=     ICD10      F209
# 88  9mdiC5WU0fjXZOm0qjwaqCPCMJP/VeZCgJdtXiJeQiI=     ICD10      F201
# 89  1PH3wiM03cBGfc9RHh/a8Djt1dhhDhY5Of0Xr5RKJ6U=     ICD10      F200
# 90  osPl1Hlg768ylEKh3To5aOxhBn62BcMVoF+RDf+WgxE=     ICD10      F201
# 91  L5leldYcm8OCDM84J/ClTgtcr1Y+Ug1HbynnAmHNXg4=     ICD10      F209
# 92  OgE0jJy+Kl7/JhN0uRdPNQNwzfKmZ5NNxO5cTmtbLws=     ICD10      F209
# 93  67gOSR5z/KHxXYiH5mo30KCc0LD77zCcdJHs8NAfaO0=     ICD10      F209
# 94  XgLgBEBK5244+DsWiv+2qZn+feAvpkVRYaGsHrrmyIY=     ICD10      F209
# 95  YXyMf/NaQYv5c5lpmoSvdBG5NmpFaGqdm+WyS5nmMFE=     ICD10      F209
# 96  NhbjXcyGPyDs2CX1FDW0qMWyEwNEJ+fctkCVa1k3SrE=     ICD10      F209
# 97  D38wJYDg5C/edgGLqcGECprsGloWZ4GK0sG2ZG4lVis=     ICD10      F209
# 98  XXNL+jSZ3FEZv+Woeh7xx73DZ6HCirdhtwDe3Dx9564=     ICD10      F209
# 99  82+Nw+8qLCsucKHxP8qfn/yElFbhnXMRX+OXzkX7uME=     ICD10      F209
#
#    diagnosis_sequence statement_from statement_to min_service_from  \
# 0                   3           None         None       2016-01-19
# 1                   1           None         None       2016-01-19
# 2                   1           None         None       2016-01-19
# 3                   1     2016-01-19   2016-01-19       2016-01-19
# 4                   4     2016-01-19   2016-01-24             None
# 5                   1           None         None       2016-01-19
# 6                   1           None         None       2016-01-19
# 7                   2           None         None       2016-01-19
# 8                   1     2016-01-19   2016-01-19       2016-01-19
# 9                   1           None         None       2016-01-19
# 10                  1     2016-01-19   2016-01-19       2016-01-19
# 11                  7           None         None       2016-01-19
# 12                  1           None         None       2016-01-19
# 13                  1     2016-01-19   2016-01-20       2016-01-19
# 14                  6     2016-01-19   2016-01-21             None
# 15                  1           None         None       2016-01-19
# 16                  8     2016-01-19   2016-01-20       2016-01-19
# 17                  1           None         None       2016-01-19
# 18                  1     2016-01-19   2016-01-19       2016-01-19
# 19                  1           None         None       2016-01-19
# 20                  1           None         None       2016-01-19
# 21                  1           None         None       2016-01-19
# 22                  1     2016-01-19   2016-01-19       2016-01-19
# 23                  1           None         None       2016-01-19
# 24                  1     2016-01-19   2016-01-19       2016-01-19
# 25                  1     2016-01-19   2016-01-19       2016-01-19
# 26                  2           None         None       2016-01-19
# 27                  1           None         None       2016-01-19
# 28                  1     2016-01-19   2016-02-01       2016-01-19
# 29                  2     2016-01-19   2016-01-19       2016-01-19
# ..                ...            ...          ...              ...
# 70                  1           None         None       2016-01-19
# 71                  3     2016-01-19   2016-01-19       2016-01-19
# 72                  1           None         None       2016-01-19
# 73                  2           None         None       2018-04-09
# 74                  4           None         None       2018-08-03
# 75                  1           None         None       2018-07-15
# 76                  1     2018-08-02   2018-08-09             None
# 77                  1           None         None       2018-07-24
# 78                  1           None         None       2018-05-16
# 79                  1           None         None       2018-08-09
# 80                  1     2018-07-16   2018-07-18       2018-07-16
# 81                  1           None         None       2018-01-30
# 82                  1     2018-07-01   2018-07-31       2018-07-01
# 83                  1           None         None       2018-08-09
# 84                  1           None         None       2018-08-08
# 85                  1           None         None       2018-07-24
# 86                  1           None         None       2018-08-06
# 87                  1           None         None       2018-07-20
# 88                  1           None         None       2018-05-26
# 89                  1           None         None       2018-08-10
# 90                  1           None         None       2018-07-26
# 91                  2           None         None       2017-10-10
# 92                  1     2018-07-17   2018-07-17       2018-07-17
# 93                  2           None         None       2018-08-08
# 94                  1           None         None       2018-08-09
# 95                  1     2018-08-07   2018-08-07       2018-08-07
# 96                  1           None         None       2018-08-08
# 97                  1     2018-08-13   2018-08-13       2018-08-13
# 98                  1           None         None       2018-08-12
# 99                  1           None         None       2018-08-06
#
#    max_service_to received_date year_of_service data_source load_indicator  \
# 0      2016-01-20    2016-02-22      2016-01-19      CONDOR             HF
# 1      2016-01-19    2018-03-20      2016-01-19      CONDOR             HF
# 2      2016-01-19    2016-02-19      2016-01-19      CONDOR             HF
# 3      2016-01-19    2016-02-02      2016-01-19      CONDOR             HF
# 4            None    2016-01-26      2016-01-19      CONDOR             HF
# 5      2016-01-19    2016-01-28      2016-01-19      CONDOR             HF
# 6      2016-01-19    2016-02-13      2016-01-19      CONDOR             HF
# 7      2016-01-30    2016-02-07      2016-01-19      CONDOR             HF
# 8      2016-01-19    2016-01-22      2016-01-19      CONDOR             HF
# 9      2016-01-19    2016-04-12      2016-01-19      CONDOR             HF
# 10     2016-01-19    2016-02-02      2016-01-19      CONDOR             HF
# 11     2016-01-19    2016-01-20      2016-01-19      CONDOR             HF
# 12     2016-01-19    2016-02-04      2016-01-19      CONDOR             HF
# 13     2016-01-20    2016-02-01      2016-01-19      CONDOR             HF
# 14           None    2016-01-29      2016-01-19      CONDOR             HF
# 15     2016-01-19    2016-04-05      2016-01-19      CONDOR             HF
# 16     2016-01-20    2016-02-02      2016-01-19      CONDOR             HF
# 17     2016-01-19    2016-02-09      2016-01-19      CONDOR             HF
# 18     2016-01-19    2016-01-21      2016-01-19   ALBATROSS              H
# 19     2016-01-19    2016-02-24      2016-01-19      CONDOR             HF
# 20     2016-01-19    2016-06-02      2016-01-19      CONDOR             HF
# 21     2016-01-19    2016-03-22      2016-01-19      CONDOR             HF
# 22     2016-01-19    2016-02-28      2016-01-19      CONDOR             HF
# 23     2016-01-19    2016-02-08      2016-01-19      CONDOR             HF
# 24     2016-01-19    2016-04-08      2016-01-19   ALBATROSS              H
# 25     2016-01-19    2016-01-30      2016-01-19      CONDOR             HF
# 26     2016-01-19    2016-06-15      2016-01-19      CONDOR             HF
# 27     2016-01-19    2016-02-12      2016-01-19      CONDOR             HF
# 28     2016-01-19    2016-05-23      2016-01-19      CONDOR             HF
# 29     2016-01-19    2016-01-22      2016-01-19      CONDOR             HF
# ..            ...           ...             ...         ...            ...
# 70     2016-01-19    2016-02-25      2016-01-19      CONDOR             HF
# 71     2016-01-19    2016-02-02      2016-01-19      CONDOR             HF
# 72     2016-01-19    2016-01-30      2016-01-19      CONDOR             HF
# 73     2018-04-09    2018-08-15      2018-04-09      CONDOR              I
# 74     2018-08-03    2018-08-14      2018-08-03      CONDOR              I
# 75     2018-07-21    2018-08-15      2018-07-15      CONDOR              I
# 76           None    2018-08-15      2018-08-02      CONDOR              I
# 77     2018-07-26    2018-08-15      2018-07-24      CONDOR              I
# 78     2018-05-16    2018-08-15      2018-05-16      CONDOR              I
# 79     2018-08-09    2018-08-15      2018-08-09      CONDOR              I
# 80     2018-07-18    2018-08-15      2018-07-16      CONDOR              I
# 81     2018-01-30    2018-08-14      2018-01-30      CONDOR              I
# 82     2018-07-01    2018-08-15      2018-07-01      CONDOR              I
# 83     2018-08-09    2018-08-15      2018-08-09      CONDOR              I
# 84     2018-08-08    2018-08-15      2018-08-08      CONDOR              I
# 85     2018-07-24    2018-08-15      2018-07-24      CONDOR              I
# 86     2018-08-10    2018-08-15      2018-08-06      CONDOR              I
# 87     2018-07-20    2018-08-15      2018-07-20      CONDOR              I
# 88     2018-07-14    2018-08-15      2018-05-26      CONDOR              I
# 89     2018-08-10    2018-08-15      2018-08-10      CONDOR              I
# 90     2018-07-26    2018-08-15      2018-07-26      CONDOR              I
# 91     2017-10-10    2018-08-15      2017-10-10      CONDOR              I
# 92     2018-07-17    2018-08-15      2018-07-17      CONDOR              I
# 93     2018-08-08    2018-08-15      2018-08-08      CONDOR              I
# 94     2018-08-09    2018-08-15      2018-08-09      CONDOR              I
# 95     2018-08-07    2018-08-15      2018-08-07      CONDOR              I
# 96     2018-08-08    2018-08-15      2018-08-08      CONDOR              I
# 97     2018-08-13    2018-08-15      2018-08-13      CONDOR              I
# 98     2018-08-12    2018-08-15      2018-08-12      CONDOR              I
# 99     2018-08-09    2018-08-15      2018-08-06      CONDOR              I
#
#     drg_patient_id       etl_create_ts       etl_update_ts
# 0              NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 1      109717169.0 2018-03-22 00:00:00 2018-03-22 00:00:00
# 2      318661281.0 2016-05-13 00:00:00 2016-05-13 00:00:00
# 3              NaN 2016-05-12 00:00:00 2016-05-12 00:00:00
# 4              NaN 2016-03-02 00:00:00 2016-03-02 00:00:00
# 5              NaN 2016-03-02 00:00:00 2016-03-02 00:00:00
# 6              NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 7              NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 8              NaN 2016-03-02 00:00:00 2016-03-02 00:00:00
# 9      303074976.0 2016-06-22 00:00:00 2016-06-22 00:00:00
# 10     206046254.0 2016-05-12 00:00:00 2016-05-12 00:00:00
# 11             NaN 2016-03-02 00:00:00 2016-03-02 00:00:00
# 12     164220339.0 2016-05-12 00:00:00 2016-05-12 00:00:00
# 13             NaN 2016-05-12 00:00:00 2016-05-12 00:00:00
# 14     341968332.0 2016-03-02 00:00:00 2016-03-02 00:00:00
# 15     320637521.0 2016-06-22 00:00:00 2016-06-22 00:00:00
# 16     163696170.0 2016-05-12 00:00:00 2016-05-12 00:00:00
# 17             NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 18             NaN 2017-08-01 12:00:00 2017-08-01 12:00:00
# 19             NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 20     295911689.0 2016-06-22 00:00:00 2016-06-22 00:00:00
# 21             NaN 2016-06-22 00:00:00 2016-06-22 00:00:00
# 22             NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 23             NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 24     174147109.0 2017-08-01 12:00:00 2017-08-01 12:00:00
# 25     116278548.0 2016-03-02 00:00:00 2016-03-02 00:00:00
# 26             NaN 2016-06-23 00:00:00 2016-06-23 00:00:00
# 27             NaN 2016-05-13 00:00:00 2016-05-13 00:00:00
# 28     256000944.0 2016-06-22 00:00:00 2016-06-22 00:00:00
# 29     218883101.0 2016-03-02 00:00:00 2016-03-02 00:00:00
# ..             ...                 ...                 ...
# 70     197403788.0 2016-05-13 00:00:00 2016-05-13 00:00:00
# 71     320428365.0 2016-05-12 00:00:00 2016-05-12 00:00:00
# 72     323810185.0 2016-03-02 00:00:00 2016-03-02 00:00:00
# 73             NaN 2018-08-17 00:00:00 2018-08-17 00:00:00
# 74     257693457.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 75     318098867.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 76     237613857.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 77             NaN 2018-08-17 00:00:00 2018-08-17 00:00:00
# 78     128494914.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 79     285096166.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 80     291707032.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 81             NaN 2018-08-17 00:00:00 2018-08-17 00:00:00
# 82     114102266.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 83     285096166.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 84     226941694.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 85     113455576.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 86     283321440.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 87     304887723.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 88     277860643.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 89     121604975.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 90     191768756.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 91     320339874.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 92     140639248.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 93     218531271.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 94     224207302.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 95             NaN 2018-08-17 00:00:00 2018-08-17 00:00:00
# 96     335592305.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 97     320658514.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 98     229873781.0 2018-08-17 00:00:00 2018-08-17 00:00:00
# 99     205999935.0 2018-08-17 00:00:00 2018-08-17 00:00:00
#
# [100 rows x 17 columns]

# %%
# %%read_sql
# create or replace table st_scz_comorb as
#     select a.*,
#            b.diagnosis as diag2
# from
#     st_scz_comorb1 a
# inner join
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS b
# on a.claim_number=b.claim_number
# Out:
# Query started at 10:33:48 PM India Standard Time; Query executed in 4.97 m
#                                       status
# 0  Table ST_SCZ_COMORB successfully created.

# %%
# %%read_sql df
# select * from st_scz_comorb
# Out:
# Query started at 10:41:57 PM India Standard Time; Query executed in 0.46 m
#             patient_id                              claim_number diagnosis  \
# 0     BdXTMyPE5MAxNktf  vul_cbfca1bc-ad0d-4274-bc7d-b0888441732e      F201
# 1     N9sS+W1B2tEVPxg9                        298309000000210018      F200
# 2     802XX1FPi0kxxrAP  vul_9c8453a8-1864-43c4-931d-d107d0190db4      F209
# 3     6LDfyOpwc2d9P89v                             vul_178403323      F209
# 4     ciEJwAbjMtzxxoqw                     con_EI081518240995725      F200
# 5     FyVQzxP1zVnU6sQN                        298309000000116570      F209
# 6     15j09uRHyEyeIzK2                     con_EI081418237041543      F200
# 7     Qr4S8Z2L9/7HUDtE                     con_EP081418737240811      F200
# 8     TVEHky6lDnXwXm0T                     con_EI081518237845026      F200
# 9     SHrbB6XRd4XKjiRV                        298310000000299692      F209
# 10    wbndLCcV62q59v95                        298309000000312357      F203
# 11    15j09uRHyEyeIzK2                     con_EI081418237041543      F200
# 12    xF10Ul+xiNqIMshE                     con_EI081418237090431      F200
# 13    QcAQTxRuyTqijczO                     con_EP081518741333741      F209
# 14    nlFy6cWMKzahNot7                     con_EI081518239834107      F209
# 15    pzDkgJKKnFi3pGk6                             vul_178707937     F2089
# 16    duLen6bVvbbNBTsL  vul_5b0e4f23-d456-4f0e-902d-2820f76d7ac4      F209
# 17    PmL8NEQP5Pvfb5Qp  vul_1cf6820e-ae6a-4cfd-a292-0a85da29d0bc      F209
# 18    btHj111s3mFsXe8S                            alb_1748670606      F209
# 19    duLen6bVvbbNBTsL  vul_5b0e4f23-d456-4f0e-902d-2820f76d7ac4      F209
# 20    +mWmUDR62npLbxWO  vul_2240d307-9602-431a-8255-b76430ee38cc      F200
# 21    SfOFg4720YQgEgHK                        298346000000076894      F209
# 22    wGMmC9DiByUjT+Rk                     con_EI081618245724532      F209
# 23    F2Oamg4aKPZpQlvL                     con_EI081518241490386      F200
# 24    jUOZkWOldMc8eAa0                     con_EI081618245624150      F200
# 25    m8IVvV/vL76x0HBw                     con_EI081618244306511      F209
# 26    KOb/HXpPg6fd6WoS                     con_EI081618244091857      F209
# 27    2IlRxM62t1CVhkf8                     con_EI081618244082469     F2089
# 28    FKly9HcAlV9ozBby                     con_EP081618742765662      F200
# 29    0RUwfJNuSUVjIX4n                        298345000000382896      F209
# ...                ...                                       ...       ...
# 4068  lzgtD2XLGAYyXV/3                     con_EI081618244017176      F209
# 4069  MyCg5oD55xvMWhXQ                        298345000000007377      F200
# 4070  0RUwfJNuSUVjIX4n                        298345000000382896      F209
# 4071  r1m9BI6g2DgehFYm                        298346000000296477      F209
# 4072  QsEUvnjRbCIQ3OKj                     con_EP081618742354117      F200
# 4073  +1VTlmLW9nOeEYmk                     con_EP081618744527826      F200
# 4074  wLdwQwLphdXvncLK                     con_EP081618744266162      F209
# 4075  Ay4k/ttyeQtmkFbN                     con_EP081618744095666      F209
# 4076  cYO6GTOU/l6sLsHI                     con_EP081618744405142     F2081
# 4077  bTamAl0uBpxLo9We                     con_EP081618745633783      F200
# 4078  cIR0hrcgbrAg+JQC                     con_EI081518241556789      F209
# 4079  6r8pFQHvw0q7IC+Q                     con_EP081618744179507     F2089
# 4080  70n6jMzg0DI2yBcA                     con_EP081618743941944      F200
# 4081  PXXf30bjfSTdtC0h                     con_EP081618743929864      F209
# 4082  8p6I22LXxtMxMyW6                     con_EI081618245427077      F209
# 4083  KOb/HXpPg6fd6WoS                     con_EI081618244091857      F209
# 4084  02R+fCw7vWY0hyoI                     con_EI081618243774268      F209
# 4085  JCo3dCXBgzuYKYfC                     con_EP081618742353626      F209
# 4086  jUOZkWOldMc8eAa0                     con_EI081618245624150      F200
# 4087  fvq/m6zsvOoUZ/QF                     con_EI081618243739088      F200
# 4088  sUzrLE4Gn1MU5Mb8                     con_EI081618245342477      F209
# 4089  CrTol85QJJzqDRup                     con_EP081618744539097      F209
# 4090  XH61EpTXRnPLBOPh                     con_EI081618245149660      F209
# 4091  sh86pLCZA5UqIGKJ                     con_EI081618245622695      F200
# 4092  AyA4Xys4hJSNxKbu                        298345000000365617      F203
# 4093  ZGZJXhnjE+/wiLIs  vul_74f68b1c-802e-47c4-b1ee-36bfc5124384      F200
# 4094  /Rob8qm6FnIXjibE                             vul_178811535     F2089
# 4095  wyToKjpN6gJJuoW6  vul_37e10a79-2e45-488c-b68f-58269cc95b87      F209
# 4096  /Rob8qm6FnIXjibE                             vul_178811535     F2089
# 4097  quscJvryM6ubU11S                        298388000000005023      F209
#
#      diagnosis_sequence year_of_service   diag2
# 0                     3      2018-06-01  G40909
# 1                     0      2018-08-04   I2510
# 2                     6      2018-07-01  H25013
# 3                     1      2018-07-18     F54
# 4                     3      2018-08-09    F330
# 5                     3      2018-08-10    E039
# 6                    11      2018-07-04    R042
# 7                     1      2018-07-23    F422
# 8                     4      2018-06-03    Z483
# 9                     8      2018-08-09   R0602
# 10                    0      2018-08-10    F203
# 11                   11      2018-07-04  Z87891
# 12                    A      2018-06-01    G894
# 13                    1      2018-07-26    F919
# 14                   12      2018-08-03  L03116
# 15                    7      2018-07-01   F0280
# 16                    3      2018-07-27   E6609
# 17                    6      2018-06-12  I70213
# 18                    3      2018-08-09    E039
# 19                    3      2018-07-27    Z125
# 20                    1      2018-07-26  Z79899
# 21                    1      2018-08-08  I82513
# 22                    A      2018-08-01    F339
# 23                    7      2018-07-01    E119
# 24                    A      2018-08-09    G894
# 25                    8      2018-08-09    R079
# 26                    4      2018-08-11    E282
# 27                    1      2018-07-06    R627
# 28                    2      2018-08-01    Q800
# 29                    1      2018-07-27   Z9114
# ...                 ...             ...     ...
# 4068                  A      2018-06-04    F209
# 4069                  1      2018-08-07    F200
# 4070                  1      2018-07-27    F209
# 4071                  1      2018-08-12    F209
# 4072                  1      2018-08-13    F200
# 4073                  1      2018-08-13    F200
# 4074                  1      2018-05-04    F209
# 4075                  1      2018-08-09    F209
# 4076                  5      2018-08-13   F2081
# 4077                  1      2018-07-05    F200
# 4078                  1      2018-08-11    F209
# 4079                  4      2018-08-02  G40101
# 4080                  1      2018-08-10    F200
# 4081                  1      2018-06-19    F209
# 4082                  2      2018-07-01    F209
# 4083                  4      2018-08-11    F209
# 4084                 10      2018-08-11    F209
# 4085                  1      2018-08-15    F209
# 4086                  A      2018-08-09    F200
# 4087                  1      2018-07-25    F200
# 4088                  7      2018-08-09    F209
# 4089                  1      2018-07-02    F209
# 4090                 14      2018-08-09    J449
# 4091                  1      2018-08-05    L219
# 4092                  9      2018-08-06    F319
# 4093                  A      2016-11-01    F200
# 4094                 12      2018-07-01    R278
# 4095                  4      2018-08-06    N390
# 4096                 12      2018-07-01     I10
# 4097                  6      2018-08-10    E119
#
# [4098 rows x 6 columns]

# %%
df.to_excel("out/other_comorb.xlsx", index=False)

# %%
# %%read_sql
#
# create or replace table st_scz_obs_cohort as
#
# select
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
#     claim_number,
#     diagnosis,
#     diagnosis_sequence,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
# where
#     diagnosis in (select distinct value from st_scz_ref where cat2 = 'scz' and deactive_date is null)
#     and year_of_service between '2015-07-01' and '2017-06-30'
# Out:
# Query started at 04:18:42 PM India Standard Time; Query executed in 21.94 m
#                                           status
# 0  Table ST_SCZ_OBS_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_scz_obs_cohort where left(patient_id, 5) != 'XXX -'")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                      857660

# %% [markdown]
# ## Index date

# %%
# %%read_sql
#
# create or replace table st_scz_index as
#
# select
#     patient_id,
#     min(year_of_service) as index_date
# from
#     st_scz_obs_cohort
# where
#     left(patient_id, 5) != 'XXX -'
# group by 1
# Out:
# Query started at 04:42:23 PM India Standard Time; Query executed in 0.19 m
#                                      status
# 0  Table ST_SCZ_INDEX successfully created.

# %%
snow.select("select * from st_scz_index order by index_date desc limit 5")
# Out:
#          patient_id  index_date
# 0  DgsKEn71UXdfIib/  2017-06-30
# 1  NpR7+SoEdOy55nVi  2017-06-30
# 2  /df25C9Yat3QZeKf  2017-06-30
# 3  +FPSwMo6r5gWBCPq  2017-06-30
# 4  jYlDoXdiYVn61Qaa  2017-06-30

# %%
snow.select("select count(patient_id) from st_scz_index where left(patient_id, 5) = 'XXX -'")
# Out:
#    COUNT(PATIENT_ID)
# 0                  0

# %% [markdown]
# # Continuous coverage

# %% [markdown]
# ## Cont. cov from medical claims
# <img src="in/cohort2.png", width=700>

# %% [markdown]
# ### Extract submits header

# %%
# %%read_sql
#
# create or replace table st_scz_cont_med as
#
# select
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
#     claim_number,
#     claim_type_code,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_HEADER
# where
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) in (select patient_id from st_scz_index)
#     and year_of_service between '2014-07-01' and '2018-06-30'
# Out:
# Query started at 05:28:33 PM India Standard Time; Query executed in 14.23 m
#                                         status
# 0  Table ST_SCZ_CONT_MED successfully created.

# %% [markdown]
# ### Check for duplicates

# %%
# %%read_sql
#
# select count(*) from st_scz_cont_med
# Out:
# Query started at 05:49:22 PM India Standard Time; Query executed in 0.10 m
#    COUNT(*)
# 0  69101373

# %%
# %%read_sql
#
# with t1 as (select distinct * from st_scz_cont_med)
# select count(*) from t1
# Out:
# Query started at 05:49:32 PM India Standard Time; Query executed in 0.33 m
#    COUNT(*)
# 0  68949257

# %%
# %%read_sql
#
# --drop table st_scz_cont_med_unique;
# create or replace table st_scz_cont_med_unique as
# select distinct * from st_scz_cont_med;
# drop table st_scz_cont_med;
# Out:
# Query started at 05:51:11 PM India Standard Time; Query executed in 0.25 mQuery started at 05:51:26 PM India Standard Time; Query executed in 0.05 m
#                                   status
# 0  ST_SCZ_CONT_MED successfully dropped.

# %% [markdown]
# ### Summarise medical claims

# %%
snow.drop_table("st_scz_cont_med_tally")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_scz_cont_med_tally;
# Table sandbox.st_scz_cont_med_tally dropped!

# %%
# %%read_sql
#
# create or replace table st_scz_cont_med_tally as
#
# select
#     a.patient_id,
#     sum(case
#            when datediff(d, a.index_date, b.year_of_service) between -365 and -1
#            then 1
#            else 0
#            end) as claim_tally_pre,
#     sum(case
#            when datediff(d, a.index_date, b.year_of_service) between 0 and 365
#            then 1
#            else 0
#            end) as claim_tally_post
# from
#     st_scz_index a
#         join st_scz_cont_med_unique b
#             on a.patient_id = b.patient_id
# group by 1
# Out:
# Query started at 06:01:38 PM India Standard Time; Query executed in 0.20 m
#                                               status
# 0  Table ST_SCZ_CONT_MED_TALLY successfully created.

# %% [markdown]
# ### Final counts

# %%
a = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally")
b = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally where claim_tally_pre > 0 and claim_tally_post > 0")
c = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally where claim_tally_pre > 1 and claim_tally_post > 1")
d = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally where claim_tally_pre > 2 and claim_tally_post > 2")
e = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally where claim_tally_pre > 3 and claim_tally_post > 3")
f = snow.select("select count(distinct patient_id) from st_scz_cont_med_tally where claim_tally_pre > 4 and claim_tally_post > 4")

lst = ['pts_obs_window',
       '1_claim_pre_and_post',
       '2_claims_pre_and_post',
       '3_claims_pre_and_post',
       '4_claims_pre_and_post',
       '5_claims_pre_and_post',]

pd.concat([a,b,c,d,e,f], keys=lst)
# Out:
#                          COUNT(DISTINCT PATIENT_ID)
# pts_obs_window        0                      857660
# 1_claim_pre_and_post  0                      715730
# 2_claims_pre_and_post 0                      646040
# 3_claims_pre_and_post 0                      586187
# 4_claims_pre_and_post 0                      538305
# 5_claims_pre_and_post 0                      494986

# %% [markdown]
# ## Final cohort

# %%
# %%read_sql
#
# create or replace table st_scz_cohort as
#
# select
#     patient_id,
#     index_date
# from
#     st_scz_index
# where
#     patient_id in (select patient_id
#                    from st_scz_cont_med_tally
#                    where claim_tally_pre > 1
#                    and claim_tally_pre > 1)
# Out:
# Query started at 06:08:29 PM India Standard Time; Query executed in 0.08 m
#                                       status
# 0  Table ST_SCZ_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_scz_cohort")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                      662109

# %% [markdown]
# # Raw data extracts

# %% [markdown]
# Pull all diagnoses data for the cohort of patients from July 1st 2014, to June 31st 2018
# <img src="in/cohort2.png", width=700>

# %% [markdown]
# ## Claim header

# %%
# %%read_sql
#
# create or replace table st_scz_header_all as
#
# select
#      'XXXXXXXXXXXXXXXX' as patient_id,
#      claim_number,
#      received_date,
#      claim_type_code,
#      statement_from,
#      statement_to,
#      min_service_from,
#      max_service_to,
#      total_charge,
#      total_allowed,
#      drg_code,
#      type_bill,
#      admission_date,
#      admit_type_code,
#      admit_src_code,
#      discharge_hour,
#      discharge_status,
#      new_medicare_source,
#      year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_HEADER
# where
#      claim_number in (select distinct claim_number
#                       from st_scz_cont_med_unique
#                       where patient_id in (select patient_id
#                                            from st_scz_cohort))
# Out:
# Query started at 06:10:15 PM India Standard Time; Query executed in 6.53 m
#                                           status
# 0  Table ST_SCZ_HEADER_ALL successfully created.

# %%
# %%read_sql
#
#  begin;
#  update st_scz_header_all a
#     set a.patient_id = b.patient_id
#    from st_scz_cont_med_unique b
#   where a.claim_number = b.claim_number;
# commit;
# Out:
# Query started at 06:17:17 PM India Standard Time; Query executed in 0.05 mQuery started at 06:17:20 PM India Standard Time; Query executed in 0.71 mQuery started at 06:18:03 PM India Standard Time; Query executed in 0.22 m
#                              status
# 0  Statement executed successfully.

# %%
# %%read_sql
#
# select
#     count(patient_id),
#     count(distinct patient_id),
#     sum(case
#            when patient_id = 'XXXXXXXXXXXXXXXX'
#            then 1
#            else 0
#            end) as null_pt_id,
#     sum(case
#            when left(patient_id, 5) = 'XXX -'
#            then 1
#            else 0
#            end) as faulty_pt_id
# from st_scz_header_all
# Out:
# Query started at 06:18:31 PM India Standard Time; Query executed in 0.07 m
#    COUNT(PATIENT_ID)  COUNT(DISTINCT PATIENT_ID)  null_pt_id  faulty_pt_id
# 0           64772415                      662109           0             0

# %% [markdown]
# ## Diagnoses

# %%
# %%read_sql
#
# create or replace table st_scz_dx_all as
#
# select
#     'XXXXXXXXXXXXXXXX' as patient_id,
#     claim_number,
#     diagnosis,
#     diagnosis_sequence,
#     statement_from,
#     statement_to,
#     min_service_from,
#     max_service_to,
#     received_date,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
# where
#     claim_number in (select distinct claim_number
#                      from st_scz_header_all)
# Out:
# Query started at 06:19:10 PM India Standard Time; Query executed in 7.69 m
#                                       status
# 0  Table ST_SCZ_DX_ALL successfully created.

# %%
# %%read_sql
#
# begin;
# update st_scz_dx_all a
# set a.patient_id = b.patient_id
# from st_scz_header_all b
# where a.claim_number = b.claim_number
# Out:
# Query started at 06:27:46 PM India Standard Time; Query executed in 0.05 mQuery started at 06:27:50 PM India Standard Time; Query executed in 0.69 m
#    number of rows updated  number of multi-joined rows updated
# 0               203494118                               981136

# %%
# %%read_sql
#
# select
#     count(patient_id),
#     count(distinct patient_id),
#     sum(case
#            when patient_id = 'XXXXXXXXXXXXXXXX'
#            then 1
#            else 0
#            end) as null_pt_id,
#     sum(case
#            when left(patient_id, 5) = 'XXX -'
#            then 1
#            else 0
#            end) as faulty_pt_id
#
# from st_scz_dx_all
# Out:
# Query started at 06:28:51 PM India Standard Time; Query executed in 0.10 m
#    COUNT(PATIENT_ID)  COUNT(DISTINCT PATIENT_ID)  null_pt_id  faulty_pt_id
# 0          203494118                      662109           0             0

# %% [markdown]
# ## Patient raw

# %%
# %%read_sql
#
# create or replace table st_scz_pat_all as
#
# select
#     'XXXXXXXXXXXXXXXX' as patient_id,
#     claim_number,
#     patient_gender,
#     patient_dob
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_PATIENT
# where
#     claim_number in (select distinct claim_number
#                      from st_scz_header_all)
# Out:
# Query started at 06:29:50 PM India Standard Time; Query executed in 4.83 m
#                                        status
# 0  Table ST_SCZ_PAT_ALL successfully created.

# %%
# %%read_sql
#
#  begin;
#  update st_scz_pat_all a
#     set a.patient_id = b.patient_id
#    from st_scz_header_all b
#   where a.claim_number = b.claim_number;
# commit;
# Out:
# Query started at 06:36:40 PM India Standard Time; Query executed in 0.12 mQuery started at 06:36:47 PM India Standard Time; Query executed in 0.81 mQuery started at 06:37:36 PM India Standard Time; Query executed in 0.07 m
#                              status
# 0  Statement executed successfully.

# %%
# %%read_sql
#
# create or replace table st_scz_pat_all_unique as
#
# select
#     patient_id,
#     min(patient_dob) as dob,
#     min(patient_gender) as gender
# from
#     st_scz_pat_all
# group by 1
# Out:
# Query started at 06:38:00 PM India Standard Time; Query executed in 0.09 m
#                                               status
# 0  Table ST_SCZ_PAT_ALL_UNIQUE successfully created.

# %% [markdown]
# # Master table

# %% [markdown]
# ## Aggregate comorbidity Dx

# %%
snow.select("select distinct cat3 from st_scz_ref")
# Out:
#             cat3
# 0           None
# 1       dementia
# 2   opioid abuse
# 3            OCD
# 4     depression
# 5  alcohol abuse

# %%
# %%read_sql
#
# create or replace table st_scz_comorbidites_agg as
#
# select
#     a.patient_id,
#     1 as scz,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_scz_ref
#                                 where cat3 = 'depression' and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -365 and 365
#            then 1
#            else 0
#            end) as depression,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_scz_ref
#                                 where cat3 = 'OCD' and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -365 and 365
#            then 1
#            else 0
#            end) as OCD,
#      max(case
#            when b.diagnosis in (select distinct value
#                                 from st_scz_ref
#                                 where cat3 = 'dementia' and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -365 and 365
#            then 1
#            else 0
#            end) as dementia,
#      max(case
#            when b.diagnosis in (select distinct value
#                                 from st_scz_ref
#                                 where cat3 = 'alcohol abuse' and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -365 and 365
#            then 1
#            else 0
#            end) as alcohol_abuse,
#      max(case
#            when b.diagnosis in (select distinct value
#                                 from st_scz_ref
#                                 where cat3 = 'opioid abuse' and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -365 and 365
#            then 1
#            else 0
#            end) as opioid_abuse
# from
#     st_scz_cohort a
#         join st_scz_dx_all b
#             on a.patient_id = b.patient_id
# group by 1
# Out:
# Query started at 02:40:54 PM India Standard Time; Query executed in 3.71 m
#                                               status
# 0  Table ST_SCZ_COMORBIDITES_AGG successfully cre...

# %%
snow.select("select * from st_scz_comorbidites_agg").to_excel("quick_peek.xlsx", index=False)

# %% [markdown]
# ## Patient age

# %%
# %%read_sql
#
# create or replace table st_scz_patient_demographics as
#
# select
#     a.patient_id,
#     b.gender,
#     datediff(yy, b.dob, a.index_date) as age,
#     case
#         when datediff(yy, b.dob, a.index_date) between 0 and 4 then '00-04'
#         when datediff(yy, b.dob, a.index_date) between 5 and 9 then '05-09'
#         when datediff(yy, b.dob, a.index_date) between 10 and 14 then '10-14'
#         when datediff(yy, b.dob, a.index_date) between 15 and 19 then '15-19'
#         when datediff(yy, b.dob, a.index_date) between 20 and 24 then '20-24'
#         when datediff(yy, b.dob, a.index_date) between 25 and 29 then '25-29'
#         when datediff(yy, b.dob, a.index_date) between 30 and 34 then '30-34'
#         when datediff(yy, b.dob, a.index_date) between 35 and 39 then '35-39'
#         when datediff(yy, b.dob, a.index_date) between 40 and 44 then '40-44'
#         when datediff(yy, b.dob, a.index_date) between 45 and 49 then '45-49'
#         when datediff(yy, b.dob, a.index_date) between 50 and 54 then '50-54'
#         when datediff(yy, b.dob, a.index_date) between 55 and 59 then '55-59'
#         when datediff(yy, b.dob, a.index_date) between 60 and 64 then '60-64'
#         when datediff(yy, b.dob, a.index_date) between 65 and 69 then '65-69'
#         when datediff(yy, b.dob, a.index_date) between 70 and 74 then '70-74'
#         when datediff(yy, b.dob, a.index_date) between 75 and 79 then '75-79'
#         when datediff(yy, b.dob, a.index_date) between 80 and 84 then '80-84'
#         when datediff(yy, b.dob, a.index_date) between 85 and 110 then '85+'
#         else null
#         end as age_cat
# from
#     st_scz_cohort a
#         join st_scz_pat_all_unique b
#             on a.patient_id = b.patient_id
# Out:
# Query started at 03:12:57 PM India Standard Time; Query executed in 0.08 m
#                                               status
# 0  Table ST_SCZ_PATIENT_DEMOGRAPHICS successfully...

# %% [markdown]
# ## Master table

# %%
snow.drop_table("st_scz_master_table")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_scz_master_table;
# Table sandbox.st_scz_master_table dropped!

# %%
# %%read_sql
#
# create or replace table st_scz_master_table as
#
# select
#     a.patient_id,
#     null as wt,
#     a.gender,
#     a.age,
#     a.age_cat,
#     b.scz,
#     b.depression,
#     b.OCD,
#     b.dementia,
#     b.alcohol_abuse,
#     b.opioid_abuse
#
# from
#     st_scz_patient_demographics a
#         join st_scz_comorbidites_agg b
#             on a.patient_id = b.patient_id
# Out:
# Query started at 03:16:01 PM India Standard Time; Query executed in 0.07 m
#                                             status
# 0  Table ST_SCZ_MASTER_TABLE successfully created.

# %% [markdown]
# # Summary results

# %%
snow.select("select * from st_scz_master_table limit 3")
# Out:
#          patient_id    wt gender  age age_cat  scz  depression  ocd  dementia  \
# 0  Slpile4aOuDt8d5o  None      M   62   60-64    1           0    0         0
# 1  3hyUkt5mPOKfQ585  None      M   55   55-59    1           0    0         0
# 2  D4f0BRY6WXUips7T  None      F   58   55-59    1           0    0         0
#
#    alcohol_abuse  opioid_abuse
# 0              0             0
# 1              0             0
# 2              0             0

# %%
# %%read_sql
#
# select
#     --age_cat,
#     sum(scz) as scz_pts,
#     sum(depression) as depression,
#     round(sum(depression)/sum(scz)*100, 2) as depression_perc,
#     sum(OCD) as OCD,
#     round(sum(OCD)/sum(scz)*100, 2) as OCD_perc,
#      sum(dementia) as dementia,
#     round(sum(dementia)/sum(scz)*100, 2) as dementia_perc,
#      sum(alcohol_abuse) as alcohol_abuse,
#     round(sum(alcohol_abuse)/sum(scz)*100, 2) as alcohol_abuse_perc,
#      sum(opioid_abuse) as opioid_abuse,
#     round(sum(opioid_abuse)/sum(scz)*100, 2) as opioid_abuse_perc
# from
#     st_scz_master_table
# --group by 1
# --order by 1
# Out:
# Query started at 03:20:51 PM India Standard Time; Query executed in 0.05 m
#    scz_pts  depression  depression_perc    ocd  ocd_perc  dementia  \
# 0   662109      248678            37.56  12311      1.86     75990
#
#    dementia_perc  alcohol_abuse  alcohol_abuse_perc  opioid_abuse  \
# 0          11.48          75480                11.4         20240
#
#    opioid_abuse_perc
# 0               3.06

# %%
# %%read_sql
#
# select
#     age_cat,
#     sum(scz) as scz_pts,
#     sum(depression) as depression,
#     round(sum(depression)/sum(scz)*100, 2) as depression_perc,
#     sum(OCD) as OCD,
#     round(sum(OCD)/sum(scz)*100, 2) as OCD_perc,
#      sum(dementia) as dementia,
#     round(sum(dementia)/sum(scz)*100, 2) as dementia_perc,
#      sum(alcohol_abuse) as alcohol_abuse,
#     round(sum(alcohol_abuse)/sum(scz)*100, 2) as alcohol_abuse_perc,
#      sum(opioid_abuse) as opioid_abuse,
#     round(sum(opioid_abuse)/sum(scz)*100, 2) as opioid_abuse_perc
# from
#     st_scz_master_table
# group by 1
# order by 1
# Out:
# Query started at 03:34:50 PM India Standard Time; Query executed in 0.10 m
#    age_cat  scz_pts  depression  depression_perc   ocd  ocd_perc  dementia  \
# 0    00-04       72           6             8.33     0      0.00         4
# 1    05-09      603         112            18.57    19      3.15         1
# 2    10-14     2509        1068            42.57   119      4.74        12
# 3    15-19    11203        5448            48.63   497      4.44        48
# 4    20-24    30716       12466            40.58   940      3.06       130
# 5    25-29    41732       15966            38.26  1049      2.51       231
# 6    30-34    45224       16923            37.42  1064      2.35       306
# 7    35-39    47736       17844            37.38  1031      2.16       408
# 8    40-44    46632       17557            37.65  1021      2.19       558
# 9    45-49    58688       22627            38.55  1088      1.85      1206
# 10   50-54    78126       29296            37.50  1226      1.57      2783
# 11   55-59    86505       30698            35.49  1210      1.40      5651
# 12   60-64    70996       24850            35.00  1140      1.61      8941
# 13   65-69    54431       19860            36.49   846      1.55     12305
# 14   70-74    35459       13461            37.96   475      1.34     12835
# 15   75-79    22459        8818            39.26   295      1.31     11069
# 16   80-84    14277        5684            39.81   158      1.11      8754
# 17     85+    14739        5993            40.66   133      0.90     10747
# 18    None        2           1            50.00     0      0.00         1
#
#     dementia_perc  alcohol_abuse  alcohol_abuse_perc  opioid_abuse  \
# 0            5.56              0                0.00             0
# 1            0.17              1                0.17             0
# 2            0.48             25                1.00             3
# 3            0.43            721                6.44           188
# 4            0.42           4011               13.06          1271
# 5            0.55           6383               15.30          2232
# 6            0.68           7184               15.89          2514
# 7            0.85           7522               15.76          2426
# 8            1.20           6964               14.93          2131
# 9            2.05           9036               15.40          2583
# 10           3.56          11616               14.87          2750
# 11           6.53          10437               12.07          2185
# 12          12.59           6215                8.75          1234
# 13          22.61           3260                5.99           498
# 14          36.20           1295                3.65           149
# 15          49.29            522                2.32            45
# 16          61.32            205                1.44            17
# 17          72.92             83                0.56            14
# 18          50.00              0                0.00             0
#
#     opioid_abuse_perc
# 0                0.00
# 1                0.00
# 2                0.12
# 3                1.68
# 4                4.14
# 5                5.35
# 6                5.56
# 7                5.08
# 8                4.57
# 9                4.40
# 10               3.52
# 11               2.53
# 12               1.74
# 13               0.91
# 14               0.42
# 15               0.20
# 16               0.12
# 17               0.10
# 18               0.00

# %% [markdown]
# # Notes for Swarali
#
# What you can do from here next week if you wanted to (i'm not even sure if its needed), is to update the wts column in the master table if you wanted to.
#
# Basically you need the ALS age-distribution in the US (in 5 yr age-groups) i.e. %, and the same for the RWD ALS cohort, and then reweight pts. upwards or downward to shift it to the distribution of the population based study - I haven't worked though the maths but should be easy enough.
#
# And once the weights are updated, you can calculate totals again, but based on sum of weights.
